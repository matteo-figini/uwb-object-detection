# %% [markdown]
# # SR250 UWB (Ultra-Wide Band) Radar Visualisation and Digital Beamforming

# %% [markdown]
# ## 1. Import required libraries
#
# In this part we install the required libraries for the notebook.

# %%
# Import required libraries
import numpy as np  
import matplotlib.pyplot as plt
import os
from PIL import Image
import matplotlib.patches as patches
import shutil

# %% [markdown]
# ## 2. Decluttering

# %% [markdown]
# ### 2.1 Exponentially-Weighted Moving Average
#
# The function `decluttering_ewma` implements an **Exponentially Weighted Moving Average (EWMA)** for background estimation. It's an **Infinite Impulse Response (IIR) filter**, meaning its current output depends on all past inputs, though older inputs have exponentially decreasing influence.
#
# In the initialization, the *dec_base* (background estimate) is initialized with the very first radar frame (`cirs[0, :]`). The output for the first frame is set to zero.
#
# For each subsequent frame i, the dec_base is updated using the formula:
# `dec_base = dec_base * alpha + cirs[i, :] * (1 - alpha)`
#
# alpha is the "forgetting factor" or "smoothing factor." A high alpha means the dec_base retains a large percentage (alpha) of its previous value and incorporates a small percentage (1 - alpha) of the current frame. This makes the background estimate adapt slowly to changes but remain very stable for static clutter.
#
# The decluttered output for the current frame is calculated as:
# `result[i, :] = (cirs[i, :] - dec_base) * normalization`
# The current radar frame `cirs[i, :]` is subtracted from the continuously updated dec_base. Static clutter, being present in both, will largely cancel out. Moving targets, being absent from dec_base, will remain.
#
# **normalization** is a scaling factor applied to match a specific output scale (as per the original logger's logic).
#
# *Analogy*: Imagine constantly taking a "picture" of the room. When you take a new picture, you combine 90% of your old "background picture" with 10% of the new picture. This way, your "background picture" slowly updates to reflect anything that becomes permanent, but it largely ignores temporary things (like a person walking through).
#
# **Characteristics**:
# * *Adaptive*: The background estimate continuously adapts to changes.
# * *Smooth Adaptation*: Changes in the background are incorporated smoothly and exponentially.
# * *Memory Efficient*: Only needs to store the previous dec_base, not a buffer of past frames.
# * *Good for Stable Clutter*: Very effective for suppressing truly static and consistent clutter over long periods.
# * *"Ghosting"*: If a new static object appears, it will create a "ghost" signal for a while until it is slowly absorbed into the dec_base. The duration of this ghosting depends on alpha.

# %%
def decluttering_ewma (cirs, alpha=0.99):
    """
    Performs decluttering on the time series of CIRs. It matches the logic
    of decluttering_alt in the Logger class.
    """
    if cirs.shape[0] == 0:
        return cirs
        
    # 1. Initialise the background (`dec_base`) with the data from the FIRST frame.
    dec_base = cirs[0, :].astype(np.complex64)
    
    # 2. Create an empty result matrix.
    result = np.zeros_like(cirs, dtype=np.complex64)
    
    # 3. The first frame's output is always zero, as per logger.py's logic.
    #    The result matrix is already initialised with zeros, so this is handled.
    normalization = (1 + alpha) / 2

    # 4. Loop from the SECOND frame (index 1) onwards.
    for i in range(1, cirs.shape[0]):
        # Calculate the output using the background from the *previous* step
        result[i, :] = (cirs[i, :] - dec_base) * normalization
        
        # Update the background for the *next* iteration
        dec_base = dec_base * alpha + cirs[i, :] * (1 - alpha)
        
    return result

# %% [markdown]
# ### 2.2 Simple Moving Average
#
# The function `decluttering_ma` implements a **Simple Moving Average** (SMA) for background estimation, as described in the Repole's thesis. This is a **Finite Impulse Response (FIR) filter**, meaning its current output only depends on a fixed, finite number of recent past inputs (defined by W).
#
# Formula: $\tilde{s}_{n,m}[k] = s_{n,m}[k] - \frac{1}{W} * \sum_{i = m-W+1}^{m}(s_{n,i}[k]) $
#
# The output for the first $W-1$ frames is set to zero because a full W-sized window is not yet available to compute the average background. For each frame $m$ (starting from W-1), it calculates the average of the current frame and the preceding W-1 frames.
#
# W is the window size: it defines the exact number of frames (current + W-1 previous) that are averaged to form the background estimate for that specific point in time.
# The decluttered output for the current frame is calculated subtracting the current radar frame `cirs[m, :]` from the window_average.
#
# *Analogy*: Imagine keeping a stack of the last W "pictures" of the room. To decide what's background for the current moment, you average only those W pictures. Anything that was in a picture older than W is completely forgotten.
#
# **Characteristics**:
# * *Fixed Window*: The background estimate is always based on a precise, fixed number of the most recent frames.
# * *Abrupt Adaptation*: If a new static object enters the scene, it will cause a strong "ghost" signal for exactly W frames, after which it will be fully incorporated into the background average and suppressed. Similarly, if an object leaves, it will "ghost" for W frames.
# * Memory: Requires access to (or storage of) the W most recent frames.
# * Risk of Target Suppression: If a target moves very slowly or stops for a duration longer than W frames, it will be included in the window_average and thus suppressed.

# %%
# Size of the moving windows, necessary also for DBF
W = 20

# %%
def decluttering_ma(cirs: np.ndarray, W: int) -> np.ndarray:
    """
    Performs decluttering on the time series of CIRs using a moving average
    background subtraction method, as described in Equation (9) of the thesis.

    The decluttered signal s_hat_n,m[k] is calculated as:
    s_hat_n,m[k] = s_n,m[k] - (1/W) * sum(s_n,i[k] for i from m-W+1 to m)

    Args:
        cirs (np.ndarray): Input radar data matrix of shape (time_frames, range_bins),
                           containing complex data.
        W (int): The window dimension (number of subsequent radar frames)
                 to be considered for the moving average. W must be >= 1.

    Returns:
        np.ndarray: The decluttered radar data matrix of the same shape as cirs,
                    containing complex data. The first (W-1) frames will be zeros.
    """
    if cirs.shape[0] == 0:
        return cirs
    
    if not isinstance(W, int) or W < 1:
        raise ValueError("Window size 'W' must be an integer and W >= 1.")

    num_frames, num_range_bins = cirs.shape
    result = np.zeros_like(cirs, dtype=np.complex64)

    # The thesis states: "the first scan of each window must be rejected"
    # This means for frames where a full 'W' window is not available,
    # the output is effectively zero or undefined. We'll set them to zero.
    
    # Loop from the (W-1)-th frame (0-indexed) onwards,
    # as this is the first frame for which a full 'W'-sized window is available.
    for m in range(W - 1, num_frames):
        # Define the window: from (m - W + 1) up to and including m
        # np.mean calculates the mean along axis=0 (frames) for each range bin
        window_average = np.mean(cirs[m - W + 1 : m + 1, :], axis=0)
        
        # Apply the subtraction formula: current_frame - window_average
        result[m, :] = cirs[m, :] - window_average
        
    return result

# %% [markdown]
# ## 3. Process a sample file
#
# First we load a single .npy file, applying decluttering, then show the time-distance plot obtained as an average of the data coming from the three files.

# %%
def show_time_distance_plot(matrix, title="SR250 UWB Time-Distance Heatmap"):
    """
    Visualizes the time-distance (heatmap) of radar data magnitude.
    """
    # The matrix shape is already (time, distance). We need to transpose for plotting.
    heatmap_data = matrix.T

    fig, ax = plt.subplots(figsize=(12, 5))
    im = ax.imshow(
        heatmap_data, 
        aspect='auto', 
        origin='lower', 
        cmap='viridis',
        interpolation='nearest',
        vmin=np.min(heatmap_data),
        vmax=np.percentile(heatmap_data, 99)
    )
    
    ax.set_title(title)
    ax.set_xlabel("Time (Frame Number)")
    ax.set_ylabel("Distance (Range Bin)")
    fig.colorbar(im, ax=ax, label="Average Signal Magnitude")
    
    plt.tight_layout()
    plt.show()

# %%
def load_declutter_sr250_file(filename):
    """
    Loads and declutters a single SR250 antenna file.
    """
    filename=os.path.join("/kaggle/input/datasets-uwb/SR250Mate/",filename)
    if not os.path.exists(filename):
        print(f"Warning: File not found, skipping: {filename}")
        return None

    print(f"Processing {os.path.basename(filename)}...")
    raw_frames_full = np.load(filename)  # (time, range_bins)

    # Keep only the first 50 bins
    raw_frames = raw_frames_full[:, :50]
    
    # Apply decluttering to remove the static background. 
    # Choose between the two implementations.
    # decluttered_matrix = decluttering_ewma(raw_frames)
    decluttered_matrix = decluttering_ma(raw_frames, W=20)
    
    return decluttered_matrix

# %%
def visualise_sr250(base_filename):
    """
    Loads, processes, and visualizes SR250 data from three antennas.
    Returns the list of complex decluttered matrices and their magnitudes.
    """
    # Automatically find paths for all three antennas
    file_list = []
    if "_sr250_rx0" in base_filename and "(move)" not in base_filename:
        base_path = base_filename.replace("_sr250_rx0.npy", "")
        for i in range(3):
            file_list.append(f"{base_path}_sr250_rx{i}.npy")
    else:
        print("Error: Please provide the path to an 'sr250_rx0' file.")
        return None # Return empty lists for both complex and magnitude

    # --- Process each antenna and store the resulting complex matrix ---
    all_decluttered_complex = []
    all_magnitudes = []
    for f in file_list:
        # Process the file to get the complex decluttered matrix
        decluttered_result = load_declutter_sr250_file(f)
        if decluttered_result is not None:
            # Remove the first W time frames from the decluttered data
            decluttered_result = decluttered_result[W:, :]
            print("Shape of the decluttered results: ", decluttered_result.shape)
            # Store complex data
            all_decluttered_complex.append(decluttered_result)
            # Also store magnitude for original visualization if needed
            all_magnitudes.append(np.abs(decluttered_result))
    
    if not all_decluttered_complex:
        print("Error: No data was processed. Exiting.")
        return [], []

    # Combine the magnitudes from all antennas
    combined_magnitude_matrix = np.mean(np.stack(all_magnitudes, axis=0), axis=0)
   # show_time_distance_plot(combined_magnitude_matrix, "SR250 UWB Time-Distance Heatmap - Mean of All Antennas")
    
    # Only complex data is needed for beamforming, so we return just that.
    return all_decluttered_complex

# %%
print("--- Running original visualizations ---")
visualise_sr250("/kaggle/input/datasets-uwb/SR250Mate/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004_sr250_rx0.npy")
# Out:
# --- Running original visualizations ---
# Processing (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004_sr250_rx0.npy...
# Processing (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004_sr250_rx1.npy...
# Processing (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004_sr250_rx2.npy...
# [array([[  0.        +0.j       ,   0.        +0.j       ,
#            0.        +0.j       , ...,   0.        +0.j       ,
#            0.        +0.j       ,   0.        +0.j       ],
#         [  0.        +0.j       ,   0.        +0.j       ,
#            0.        +0.j       , ...,   0.        +0.j       ,
#            0.        +0.j       ,   0.        +0.j       ],
#         [  0.        +0.j       ,   0.        +0.j       ,
#            0.        +0.j       , ...,   0.        +0.j       ,
#            0.        +0.j       ,   0.        +0.j       ],
#         ...,
#         [ -0.8999996 -9.5j      ,  -5.450012  -3.6999998j,
#           -9.300049  +6.6500015j, ..., -16.449997 -27.550018j ,
#          -40.800003 -24.350006j , -23.300003  -7.4500046j],
#         [ -3.75      +3.25j     ,  -1.3999939 +3.8999996j,
#           -2.8000488 -0.5j      , ...,   2.8499908-21.649994j ,
#          -20.949997 -17.800003j , -18.850006  -5.6500015j],
#         [ -4.800001  -5.6499996j,  -5.350006  -8.8j      ,
#           -5.6500244 -3.2999954j, ...,  -9.300003 -15.300018j ,
#          -12.25      -9.900009j ,  -6.100006  -7.5999985j]],
#        dtype=complex64),
#  array([[  0.        +0.j        ,   0.        +0.j        ,
#            0.        +0.j        , ...,   0.        +0.j        ,
#            0.        +0.j        ,   0.        +0.j        ],
#         [  0.        +0.j        ,   0.        +0.j        ,
#            0.        +0.j        , ...,   0.        +0.j        ,
#            0.        +0.j        ,   0.        +0.j        ],
#         [  0.        +0.j        ,   0.        +0.j        ,
#            0.        +0.j        , ...,   0.        +0.j        ,
#            0.        +0.j        ,   0.        +0.j        ],
#         ...,
#         [  5.4       +0.9j       ,   1.5999994 +3.75j      ,
#            1.1000061 +4.599991j  , ..., -34.649994 -27.649963j  ,
#          -16.199982  -9.5j       ,   4.100006 +14.j        ],
#         [ -4.25      +3.85j      ,  -3.1000004 +1.j        ,
#           -2.        -4.800003j  , ..., -60.75     -33.799988j  ,
#          -19.        +0.7000122j ,  11.550018 +24.850006j  ],
#         [  1.4       -2.1j       ,  -2.8500004 -0.19999981j,
#           -0.8000183 +3.800003j  , ..., -37.5      -30.799988j  ,
#           -7.4499817 +3.600006j  ,   7.75     +19.25j      ]],
#        dtype=complex64),
#  array([[  0.         +0.j       ,   0.         +0.j       ,
#            0.         +0.j       , ...,   0.         +0.j       ,
#            0.         +0.j       ,   0.         +0.j       ],
#         [  0.         +0.j       ,   0.         +0.j       ,
#            0.         +0.j       , ...,   0.         +0.j       ,
#            0.         +0.j       ,   0.         +0.j       ],
#         [  0.         +0.j       ,   0.         +0.j       ,
#            0.         +0.j       , ...,   0.         +0.j       ,
#            0.         +0.j       ,   0.         +0.j       ],
#         ...,
#         [  0.10000038 -3.9j      ,   0.20000076 -1.j       ,
#           -4.1000004  +1.25j     , ..., -16.200005   +3.4500008j,
#          -11.350002  +11.1j      ,  -9.2       +11.299995j ],
#         [  4.         +3.95j     ,  -0.79999924 +8.6j      ,
#           -3.0499992  +4.950001j , ..., -20.349998  +13.25j     ,
#          -15.1       +20.6j      , -11.950001  +23.199997j ],
#         [ -3.         -4.7j      ,  -1.6000004  -4.05j     ,
#           -1.7999992  -2.8500004j, ..., -21.550003  +16.2j      ,
#          -11.75      +15.65j     ,  -3.9500003  +6.949997j ]],
#        dtype=complex64)]

# %% [markdown]
# ## Apply Digital Beamforming

# %%
# --- Radar Parameters ---
d = 2.4e-2             # Distance between rx antenna elements for azimuth (rx0 and rx1)
f = 7.25e9           # Center frequency of radar pulse
c = 299792458        # Speed of light

l = c/f              # Wavelength
k = 2*np.pi/l        # Wavenumber

min_angle = -45
max_angle = 45
num_angles = round((max_angle - min_angle + 1) / 2)
print("Number of angles considered: ", num_angles)
beam_steering_angles = np.deg2rad(np.linspace(min_angle, max_angle, num_angles))

# Receivers to be considered, RX0 and RX2
receivers = [0, 2]
# Initial time frame for window plot
initial_time_frame = 0
# Target time frame for window plot, 20 time frames correspond to 1 second
target_time_frame = 20
DISTANCE_MIN=0
DISTANCE_MAX=5
FOMO_GRID_SIZE = (16, 16) # (altezza, larghezza)
OBJECT_CLASS_ID = 0
# Out:
# Number of angles considered:  46

# %%
# --- Beamforming Helper Functions ---
def compute_bf_weights(angle_range, delta, k, num_rx_elements):
    """
    Computes beamforming weights for a linear array.
    
    Args:
        angle_range (np.ndarray): Array of angles (in radians) for which to compute weights.
        delta (float): Distance between adjacent antenna elements.
        k (float): Wavenumber (2*pi/lambda).
        num_rx_elements (int): Number of receive antenna elements.
        
    Returns:
        np.ndarray: Beamforming weights of shape (len(angle_range), num_rx_elements).
    """
    bf_weights = np.zeros((angle_range.shape[0], num_rx_elements), dtype="complex")
    for i in range(angle_range.shape[0]):      # Loop over angles
        for j in range(num_rx_elements):       # Loop over antenna elements
            # Phase shift for element j at angle_range[i]
            bf_weights[i, j] = np.exp(-1j * k * delta * j * np.sin(angle_range[i]))
    return bf_weights

# %%
def perform_azimuth_beamforming(rx0_complex_data, rx1_complex_data, d, k, beam_steering_angles):
    """
    Performs azimuth beamforming on complex data from rx0 and rx1 antennas.
    This version processes all time frames individually, producing a 3D output.
    
    Args:
        rx0_complex_data (np.ndarray): Complex CIRs from rx0 (time_frames, range_bins).
        rx1_complex_data (np.ndarray): Complex CIRs from rx1 (time_frames, range_bins).
        d (float): Distance between rx0 and rx1 antennas (element spacing).
        k (float): Wavenumber (2*pi/lambda).
        beam_steering_angles (np.ndarray): Array of angles in radians for beamsteering.

    Returns:
        np.ndarray: Beamformed data of shape (time_frames, range_bins, angles), or None if error.
    """

    # Resize the range bins due to slight mismatch
    rx0_complex_data = rx0_complex_data[:, 0:45]
    rx1_complex_data = rx1_complex_data[:, 2:47]
    
    if rx0_complex_data is None or rx1_complex_data is None:
        print("Error: Input data for beamforming is missing.")
        return None
    if rx0_complex_data.shape != rx1_complex_data.shape:
        print("Error: rx0 and rx1 data shapes do not match. Cannot perform beamforming.")
        return None
    else:
        print(f"Shape of the first antenna: {rx0_complex_data.shape}, with dtype {rx0_complex_data.dtype}")
        print(f"Shape of the second antenna: {rx1_complex_data.shape}, with dtype {rx1_complex_data.dtype}")
    
    num_time_frames = rx0_complex_data.shape[0]   # Slow time
    num_range_bins = rx0_complex_data.shape[1]    # Fast time
    num_rx_elements = 2
    num_angles = beam_steering_angles.shape[0]    # Number of angles to be considered

    # Compute beamforming weights. These are constant for all time frames and range bins.
    bf_weights = compute_bf_weights(beam_steering_angles, d, k, num_rx_elements)

    # Initialize a 3D array to store beamformed results
    beamformed_3d_result = np.zeros((num_time_frames, num_range_bins, num_angles), dtype=complex)
    print(f"Starting beamforming over {num_time_frames} time frames and {num_range_bins} range bins...")

    # This version performs the same carried out by bf.py but exploiting NumPY vectorized operations.
    for t in range(num_time_frames):
        # Extract the complex CIRs for the current time frame from both RX antennas       
        # and stack them to form the input for beamforming for the current frame.
        # data_for_current_frame_all_bins will have shape (num_rx_elements, range_bins)
        data_for_current_frame_all_bins = np.stack([rx0_complex_data[t, :], rx1_complex_data[t, :]], axis=0)

        # Perform matrix multiplication for all range bins in the current frame simultaneously
        # (num_angles, num_rx_elements) @ (num_rx_elements, num_range_bins)
        # Result of dot product: (num_angles, num_range_bins)
        beamformed_slice_transposed = np.dot(bf_weights, data_for_current_frame_all_bins)
        
        # Transpose the result to get (range_bins, angles) for this time slice
        beamformed_3d_result[t, :, :] = beamformed_slice_transposed.T
            
    print("Beamforming complete for all frames and range bins.")
    return beamformed_3d_result

# %%
def show_range_angle_plot(matrix, angles_rad, title="Beamformed Range-Azimuth Image", range_conversion_factor=10, output_path= "/kaggle/working/dataset_fomo/"):
    """
    Visualizes the beamformed data as a 2D heatmap (Distance vs. Azimuth Angle).
    Converts range bins to meters for visualization.
    
    Args:
        matrix (np.ndarray): The beamformed data, shape (range_bins, angles).
                              This should be the magnitude for plotting.
        angles_rad (np.ndarray): Array of angles in radians used for beamsteering.
        title (str): Title for the plot.
        range_conversion_factor (int/float): Number of bins per meter.

        It also saves the plot as a .png image without axis nor title
    """
    output_path= f"/kaggle/working/{title}"

    dpi = 100
    
    heatmap_data = matrix
    fig, ax = plt.subplots(figsize=(12, 5))

    angles_deg = np.rad2deg(angles_rad)

    # Convert range bins to meters for the y-axis extent
    min_range_meters = 0
    max_range_meters = heatmap_data.shape[0] / range_conversion_factor # (number of range bins) / (bins per meter)

    # extent defines (left, right, bottom, top) in data coordinates
    # For imshow: x-axis maps to columns, y-axis maps to rows.
    # matrix is (rows=range_bins, cols=angles) -> extent = [x_min, x_max, y_min, y_max]
    extent = [angles_deg.min(), angles_deg.max(), min_range_meters, max_range_meters] 

    im = ax.imshow(
        heatmap_data, 
        aspect='auto', 
        origin='lower', # Origin lower for distance on Y-axis (0 at bottom)
        cmap='viridis',
        interpolation='nearest',
        vmin=np.percentile(heatmap_data, 10),
        vmax=np.percentile(heatmap_data, 99),
        extent=extent # Map data coordinates to image pixels
    )
    
    ax.set_title(title)
    ax.set_xlabel("Azimuth Angle (degrees)")
    ax.set_ylabel("Distance (meters)") # Changed label to meters
    fig.colorbar(im, ax=ax, label="Beamformed Signal Magnitude")
    
    # Set x-axis ticks to display angles more meaningfully
    num_ticks_x = 7 # Example, adjust as needed
    tick_indices_x = np.linspace(0, len(angles_deg) - 1, num_ticks_x).astype(int)
    ax.set_xticks(angles_deg[tick_indices_x])
    ax.set_xticklabels([f"{a:.0f}°" for a in angles_deg[tick_indices_x]])

    # Set y-axis ticks to display meters more meaningfully
    # Determine appropriate interval for y-axis ticks based on max_range_meters
    if max_range_meters <= 1:
        y_tick_interval = 0.1
    elif max_range_meters <= 5:
        y_tick_interval = 0.5
    else:
        y_tick_interval = 1.0
    
    y_ticks = np.arange(min_range_meters, max_range_meters + y_tick_interval, y_tick_interval)
    ax.set_yticks(y_ticks)
    ax.set_yticklabels([f"{d:.1f}m" for d in y_ticks])
    
    

    plt.tight_layout()
    plt.show()
    
    #fig.savefig(output_path, bbox_inches='tight', pad_inches=0, dpi=dpi)
    plt.close(fig)

# %%
def retrieve_image_png(matrix, angles_rad, title="Beamformed Range-Azimuth Image", range_conversion_factor=10):
    output_path= f"/kaggle/working/dataset_FOMO/{title}"

    dpi = 100
    
    heatmap_data = matrix
    fig, ax = plt.subplots(figsize=(96, 96))
    ax = fig.add_axes([0, 0, 1, 1])
    #angles_deg = np.rad2deg(angles_rad)

    # Convert range bins to meters for the y-axis extent
    min_range_meters = 0
    max_range_meters = heatmap_data.shape[0] / range_conversion_factor # (number of range bins) / (bins per meter)

    # extent defines (left, right, bottom, top) in data coordinates
    # For imshow: x-axis maps to columns, y-axis maps to rows.
    # matrix is (rows=range_bins, cols=angles) -> extent = [x_min, x_max, y_min, y_max]
    extent = [min_angle, max_angle,  DISTANCE_MIN, DISTANCE_MAX] 

    im = ax.imshow(
        heatmap_data, 
        aspect='auto', 
        origin='lower', # Origin lower for distance on Y-axis (0 at bottom)
        cmap='gist_gray',
        interpolation='nearest',
        vmin=np.percentile(heatmap_data, 10),
        vmax=np.percentile(heatmap_data, 99),
        extent=extent # Map data coordinates to image pixels
    )
    
    ax.axis('off')
    fig.savefig(output_path, bbox_inches='tight', pad_inches=0, dpi=dpi)
    plt.close(fig)

# %%
def normalize_range_angle_map(matrix: np.ndarray) -> np.ndarray:
    """
    Normalizes a 2D Range-Angle map to the range [0, 1] using min-max scaling,
    as described in Equation (11) of the thesis.

    Args:
        matrix (np.ndarray): The input 2D Range-Angle map.

    Returns:
        np.ndarray: The normalized map.
    """
    min_val = np.min(matrix)
    max_val = np.max(matrix)
    if max_val == min_val: # Avoid division by zero for uniform matrices
        return np.zeros_like(matrix)
    normalized_matrix = (matrix - min_val) / (max_val - min_val)
    return normalized_matrix

# %%
def apply_bf_pipeline (base_file, rx_s = [0, 2], coherent_incoherent_avg = 1, dataset_creation= False):
    
    # Load and declutter data for all antennas
    print(f"\n--- Loading and processing data for beamforming: {os.path.basename(base_file)} ---")
    all_complex_data = visualise_sr250(base_file)
    if all_complex_data is None:
        print("Exiting..")
        return False
    # Check if rx0 and rx1 data are available for azimuth beamforming.
    rx0_data = all_complex_data[rx_s[0]]
    rx1_data = all_complex_data[rx_s[1]]
    # Perform azimuth beamforming, return a 3D array (time_frames, range_bins, angles)
    print(f"Performing azimuth beamforming using RX{rx_s[0]} and RX{rx_s[1]} data...")
    beamformed_3d_data = perform_azimuth_beamforming(rx0_data, rx1_data, d, k, beam_steering_angles)
    print(f"Shape of the beamformed data: {beamformed_3d_data.shape} with dtype {beamformed_3d_data.dtype}")
    
    # Aggregate the 3D data for 2D visualization (Range-Azimuth Heatmap)
    if beamformed_3d_data is not None and not dataset_creation:
        for i in range(6, 0, -1):
            #target_time_frame = round(beamformed_3d_data.shape[0] / i)
            target_time_frame= 10 * i
            start_point= 20
            
            if coherent_incoherent_avg == 0:
                # Coherent averaging
                print("Apply coherent averaging...")
                aggregated_beamformed_data = np.abs(np.sum(beamformed_3d_data[start_point:target_time_frame + 1, :, ], axis=0))
            elif coherent_incoherent_avg == 1:
                # Incoherent averaging
                print("Apply incoherent averaging...")
                aggregated_beamformed_data = np.sum(np.abs(beamformed_3d_data[start_point:target_time_frame + 1, :, ]), axis=0)
            else:
                # Incoherent averaging with mean
                print("Apply incoherent averaging by mean...")
                aggregated_beamformed_data = np.mean(np.abs(beamformed_3d_data[start_point:target_time_frame + 1, :, ]), axis=0)
            # Normalization
        
            normalized_beamformed_data = normalize_range_angle_map(aggregated_beamformed_data)
            title = f"Beamforming ({target_time_frame} time frames, starting from {start_point}) - {os.path.basename(base_file).replace('_sr250_rx0.npy', '')}"
            
            #show_range_angle_plot(normalized_beamformed_data, beam_steering_angles, title)
    elif dataset_creation:
            target_time_frame= 40
            aggregated_beamformed_data = np.abs(np.sum(beamformed_3d_data[:target_time_frame + 1, :, ], axis=0))
            normalized_beamformed_data = normalize_range_angle_map(aggregated_beamformed_data)
            title = f"{os.path.basename(base_file).replace('_sr250_rx0.npy', '')}"
            retrieve_image_png(normalized_beamformed_data, beam_steering_angles, title)
            print(f".png saved as {title} ")
            return True
            #show_range_angle_plot(normalized_beamformed_data, beam_steering_angles, title)
    else:
        print("Beamforming could not be completed.")
        return False

# %%
base_file_for_bf = "/kaggle/input/sr250mate-dataset/SR250Mate/14_Still position_20250618-112731_sr250_rx0.npy"
apply_bf_pipeline(base_file_for_bf, [0, 1], 1, True)
# Out:
# --- Loading and processing data for beamforming: 14_Still position_20250618-112731_sr250_rx0.npy ---
# Processing 14_Still position_20250618-112731_sr250_rx0.npy...
# Processing 14_Still position_20250618-112731_sr250_rx1.npy...
# Processing 14_Still position_20250618-112731_sr250_rx2.npy...
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the complex input data (rx0/rx1): (1200, 50), with dtype complex64
# Starting beamforming over 1200 time frames and 50 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 50, 121) with dtype complex128
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_36/3018225051.py in <cell line: 0>()
#       1 base_file_for_bf = "/kaggle/input/sr250mate-dataset/SR250Mate/14_Still position_20250618-112731_sr250_rx0.npy"
# ----> 2 apply_bf_pipeline(base_file_for_bf, [0, 1], 1, True)
#
# /tmp/ipykernel_36/1930047223.py in apply_bf_pipeline(base_file, rx_s, coherent_incoherent_avg, dataset_creation)
#      48             normalized_beamformed_data = normalize_range_angle_map(aggregated_beamformed_data)
#      49             title = f"{os.path.basename(base_file).replace('_sr250_rx0.npy', '')}"
# ---> 50             retrieve_image_png(normalized_beamformed_data, beam_steering_angles, title)
#      51             print(f".png saved as {title} ")
#      52             #show_range_angle_plot(normalized_beamformed_data, beam_steering_angles, title)
#
# /tmp/ipykernel_36/4212830395.py in retrieve_image_png(matrix, angles_rad, title, range_conversion_factor)
#      30
#      31     ax.axis('off')
# ---> 32     fig.savefig(output_path, bbox_inches='tight', pad_inches=0, dpi=dpi)
#      33     plt.close(fig)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3376                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3377
# -> 3378             self.canvas.print_figure(fname, **kwargs)
#    3379
#    3380     def ginput(self, n=1, timeout=30, show_clicks=True,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2364                 # force the figure dpi to 72), so we need to set it again here.
#    2365                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2366                     result = print_method(
#    2367                         filename,
#    2368                         facecolor=facecolor,
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2230                 "bbox_inches_restore"}
#    2231             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2232             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2233                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2234         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     507             *metadata*, including the default 'Software' key.
#     508         """
# --> 509         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     510
#     511     def print_to_buffer(self):
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     456         """
#     457         FigureCanvasAgg.draw(self)
# --> 458         mpl.image.imsave(
#     459             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#     460             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# /usr/local/lib/python3.11/dist-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1687         pil_kwargs.setdefault("format", format)
#    1688         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1689         image.save(fname, **pil_kwargs)
#    1690
#    1691
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2574                 fp = builtins.open(filename, "r+b")
#    2575             else:
# -> 2576                 fp = builtins.open(filename, "w+b")
#    2577         else:
#    2578             fp = cast(IO[bytes], fp)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/working/dataset_FOMO/14_Still position_20250618-112731.png'

# %% [markdown]
# # DEFINE TRAINING DATASET

# %%
#taken from data collection set up
#TO BE CHECKED !!!
GROUND_TRUTH_POSITIONS = {
    2: {'distance': 1.5, 'angle': -45.0},
    3: {'distance': 1.5, 'angle': 0.0},
    4: {'distance': 1.5, 'angle': 45.0},
    7: {'distance': 2.5, 'angle': -45.0},
    8: {'distance': 2.5, 'angle': 0.0},
    9: {'distance': 2.5, 'angle': 45.0},
    12: {'distance': 3.5, 'angle': -45.0},
    13: {'distance': 3.5, 'angle': 0.0},
    11: {'distance': 3.5, 'angle': 45.0},
    14: {'distance': 3.5, 'angle': -15.0} 
}

# %%
def create_fomo_label(image_name, output_path):
    """
    Create a label for FOMO from ground truth table
    """
    num_str = image_name.split('_')[0]
    
    if "(move)" in num_str:
        num_str= num_str.replace("(move)", "")
    num_str = num_str.split('-')

    positions = [int(n) for n in num_str if n!= '']
    for position_number in positions:
        if position_number not in GROUND_TRUTH_POSITIONS:
            print(f"  -> Attenzione: Posizione {position_number} non trovata. Salto etichetta.")
            return False

        gt = GROUND_TRUTH_POSITIONS[position_number]
        distance, angle = gt['distance'], gt['angle']

    
        x_norm = (angle - min_angle) / (max_angle - min_angle)
        y_norm_raw = distance / DISTANCE_MAX
        y_norm = 1.0 - y_norm_raw
    
        y_norm = np.clip(y_norm, 0.0, 1.0)
        x_norm = np.clip(x_norm, 0.0, 1.0)

    
        grid_h, grid_w = FOMO_GRID_SIZE
        box_w_norm = 1.0 / grid_w
        box_h_norm = 1.0 / grid_h
    
        #grid_col = int(x_norm * grid_w)
        #grid_row = int(y_norm * grid_h)
        grid_col = min(int(x_norm * grid_w), grid_w - 1)
        grid_row = min(int(y_norm * grid_h), grid_h - 1)
    
        x_center_norm = (grid_col + 0.5) / grid_w
        y_center_norm = (grid_row + 0.5) / grid_h

    
        label_str = f"{OBJECT_CLASS_ID} {x_center_norm:.6f} {y_center_norm:.6f} {box_w_norm:.6f} {box_h_norm:.6f}"
    
        with open(output_path, 'a') as f:
            f.write(label_str+'\n')
    
    return True

# %%
def create_label_from_png(image_path, label_path):
    """
    Analyze an image of heatmap, finding the "lighter spot"
    """
    image_path= os.path.join("/dataset_FOMO/", image_path)
    try:
        # 1. Carica l'immagine e ottieni le sue dimensioni
        with Image.open(image_path) as img:
            img_width, img_height = img.size
            
            # 2. Converti l'immagine in scala di grigi ('L' mode)
            # I colori più luminosi (come il giallo) avranno valori più alti.
            grayscale_img = img.convert('L')
            
            # Converti l'immagine in una matrice NumPy per l'analisi
            heatmap_data = np.array(grayscale_img)

    except FileNotFoundError:
        print(f"  -> ERRORE: Immagine non trovata in '{image_path}'.")
        return False
    except Exception as e:
        print(f"  -> ERRORE durante il caricamento o la conversione dell'immagine '{os.path.basename(image_path)}': {e}")
        return False

    # 3. Trova le coordinate (riga, colonna) del pixel più luminoso
    peak_coords_pixels = np.unravel_index(np.argmax(heatmap_data), heatmap_data.shape)
    peak_row, peak_col = peak_coords_pixels
    
    # 4. Normalizza le coordinate del pixel in un range [0, 1]
    # L'asse Y (verticale) corrisponde alle righe, l'asse X (orizzontale) alle colonne.
    y_norm = peak_row / img_height
    x_norm = peak_col / img_width
    
    # 5. Calcola le informazioni della cella della griglia FOMO
    grid_h, grid_w = FOMO_GRID_SIZE
    box_w_norm = 1.0 / grid_w
    box_h_norm = 1.0 / grid_h
    
    grid_col = int(x_norm * grid_w)
    grid_row = int(y_norm * grid_h)
    
    x_center_norm = (grid_col + 0.5) / grid_w
    y_center_norm = (grid_row + 0.5) / grid_h

    
    label_str = f"{OBJECT_CLASS_ID} {x_center_norm:.6f} {y_center_norm:.6f} {box_w_norm:.6f} {box_h_norm:.6f}"
    
    try:
        with open(label_path, 'w') as f:
            f.write(label_str)
        return True
    except IOError as e:
        print(f"  -> ERRORE nella scrittura del file di etichetta {label_path}: {e}")
        return False

# %%
def visualize_sample(dataset_dir="/kaggle/input/complete-dataset/dataset_FOMO", filename=None):
    """
    Visualize the bounding box
    """
    
    # Trova tutti i file immagine nel dataset
    
    image_files = [f for f in os.listdir(dataset_dir) if f.endswith(".png")]
    if not image_files:
        print(f"Nessun file .png trovato in '{dataset_dir}'")
        return

    # Se non è specificato un file, scegline uno a caso
    if filename is None:
        selected_image_file = random.choice(image_files)
    else:
        if filename not in image_files:
            print(f"File '{filename}' non trovato nel dataset. Scelgo uno a caso.")
            selected_image_file = random.choice(image_files)
        else:
            selected_image_file = filename

    # Definisci i percorsi per l'immagine e l'etichetta
    image_path = os.path.join(dataset_dir, selected_image_file)
    label_path= image_path.replace(".png",".txt")
    label_path = "/kaggle/working/8-9-13-14_Still position_20250618-150804.txt"
    
    print(f"Visualizzazione del campione: {selected_image_file}")

    # --- Carica l'immagine ---
    try:
        img = Image.open(image_path)
        img_width, img_height = img.size
    except FileNotFoundError:
        print(f"Errore: File immagine non trovato in '{image_path}'")
        return
    annotations = []  # Lista per contenere i dati di TUTTE le bounding box
    try:
        with open(label_path, 'r') as f:
            # Iteriamo su ogni riga del file
            for line in f:
                if not line.strip():  # Salta le righe vuote
                    continue
                
                try:
                    parts = line.strip().split()
                    if len(parts) != 5:
                        print(f"Attenzione: la riga '{line.strip()}' non ha 5 elementi, la salto.")
                        continue
                    
                    class_id = int(parts[0])
                    x_center_norm = float(parts[1])
                    y_center_norm = float(parts[2])
                    width_norm = float(parts[3])
                    height_norm = float(parts[4])

                    # Converti le coordinate normalizzate in coordinate pixel
                    box_width = width_norm * img_width
                    box_height = height_norm * img_height
                    x_min = (x_center_norm * img_width) - (box_width / 2)
                    y_min = (y_center_norm * img_height) - (box_height / 2)
                    
                    # Salva i dati calcolati in un dizionario e aggiungilo alla lista
                    annotations.append({
                        'class_id': class_id,
                        'x_min': x_min,
                        'y_min': y_min,
                        'box_width': box_width,
                        'box_height': box_height
                    })
                except (ValueError, IndexError) as e:
                    print(f"Errore nel processare la riga '{line.strip()}': {e}. La salto.")

    except FileNotFoundError:
        print(f"Etichetta non trovata per '{selected_image_file}' in {label_path}. Mostro solo l'immagine.")
    except IOError as e:
        print(f"Errore nella lettura del file di etichetta '{label_path}': {e}")
        return

    # --- MODIFICA 2: Disegna l'immagine e TUTTI i bounding box ---
    fig, ax = plt.subplots(1, figsize=(10, 10))
    ax.imshow(img)
    
    # Controlla se la lista 'annotations' contiene qualcosa
    if annotations:
        print(f"Trovate e disegnate {len(annotations)} etichette.")
        # Itera su ogni etichetta salvata e disegna un rettangolo per ciascuna
        for ann in annotations:
            # Crea una patch rettangolare per l'annotazione corrente
            rect = patches.Rectangle(
                (ann['x_min'], ann['y_min']), 
                ann['box_width'], 
                ann['box_height'], 
                linewidth=2, 
                edgecolor='r',
                facecolor='none'
            )
            
            # Aggiungi il rettangolo all'immagine
            ax.add_patch(rect)

            # Aggiungi un'etichetta di testo sopra il box
            plt.text(
                ann['x_min'], 
                ann['y_min'] - 10,  # Posiziona il testo leggermente sopra il box
                f"ID: {ann['class_id']}", 
                color='red', 
                fontsize=12, 
                bbox=dict(facecolor='white', alpha=0.6, pad=1)
            )
    else:
        # Questo messaggio appare se il file di etichette non esiste o è vuoto
        print("Nessuna etichetta valida trovata da disegnare.")

    ax.set_title(f"Verifica: {selected_image_file}")
    ax.axis('off')
    plt.show()

# %%
#shutil.rmtree('/kaggle/working/dataset_FOMO')
os.mkdir("/kaggle/working/dataset_FOMO")

# %%
# create dataset
def create_dataset_for_FOMO(batch: int):
    #create directory / empty the existing one
    if not os.path.isdir("/kaggle/working/dataset_FOMO"):
        os.mkdir("/kaggle/working/dataset_FOMO")
        print("folder created")
    elif not len(os.listdir('/kaggle/working/dataset_FOMO'))==0 :
        print("folder existing and not empty")
        #shutil.rmtree('/kaggle/working/dataset_FOMO')
        #os.mkdir("/kaggle/working/dataset_FOMO")
    else:
        print("folder existing but empty")
    i=0
    #iterate
    for file in os.listdir("/kaggle/input/datasets-uwb/SR250Mate/"):
        if i<batch :
            if "_sr250_rx0" in file and "(move)" not in file:
                name_to_check= file.replace("_sr250_rx0.npy",".png")
                if name_to_check not in os.listdir("/kaggle/input/partial/dataset_FOMO"):
                    if apply_bf_pipeline(file, [0, 1], 1, True):
                        i+=1
                        file=file.replace(".png",".txt")
                        #if create_fomo_label(file,f"/kaggle/working/dataset_FOMO/{file}"):
                         #   print(f"label for {file} created")
                        #else:
                         #   print(f"error in creating label for {file}")
                    else:
                        print("BeamF skipped...")
                else: 
                    print(f"file {file} already processed")
        else:
            break

# %%
#os.remove("/kaggle/working/dataset_FOMO/bounding_boxes.labels")
import os
path="/kaggle/input/complete-dataset/dataset_FOMO"
for file in os.listdir(path):
        file=file.replace(".png",".txt")
        print(f"processing file { file}")
        if create_fomo_label(file,f"/kaggle/working/{file}"):
            print(f"label for {file} created")
        else:
            print(f"error in creating label for {file}")
# Out:
# processing file 3-4-8-9_Still position_20250618-150521.txt
# label for 3-4-8-9_Still position_20250618-150521.txt created
# processing file 3-9-7-13_Still position_20250618-144439.txt
# label for 3-9-7-13_Still position_20250618-144439.txt created
# processing file 4-12_Still position_20250618-151352.txt
# label for 4-12_Still position_20250618-151352.txt created
# processing file 8-14_Still position_20250618-151230.txt
# label for 8-14_Still position_20250618-151230.txt created
# processing file 12-13-14_Still position_20250618-140232.txt
# label for 12-13-14_Still position_20250618-140232.txt created
# processing file 3-13_Still position_20250618-142324.txt
# label for 3-13_Still position_20250618-142324.txt created
# processing file 4-7-9-12_Still position_20250618-145620.txt
# label for 4-7-9-12_Still position_20250618-145620.txt created
# processing file 13-14_Still position_20250618-141413.txt
# label for 13-14_Still position_20250618-141413.txt created
# processing file 2-4-7-12_Still position_20250618-145748.txt
# label for 2-4-7-12_Still position_20250618-145748.txt created
# processing file 3-4-13-14_Still position_20250618-144858.txt
# label for 3-4-13-14_Still position_20250618-144858.txt created
# processing file 3-7-13_Still position_20250618-120843.txt
# label for 3-7-13_Still position_20250618-120843.txt created
# processing file 4-2-14 _Still position_20250618-115434.txt
# label for 4-2-14 _Still position_20250618-115434.txt created
# processing file 7-8-12-13_Still position_20250618-150643.txt
# label for 7-8-12-13_Still position_20250618-150643.txt created
# processing file 2-4-12_Still position_20250618-115616.txt
# label for 2-4-12_Still position_20250618-115616.txt created
# processing file 2-4-9-14_Still position_20250618-145914.txt
# label for 2-4-9-14_Still position_20250618-145914.txt created
# processing file 14_Still position_20250618-113914.txt
# label for 14_Still position_20250618-113914.txt created
# processing file 2-3-12-13_Still position_20250618-145024.txt
# label for 2-3-12-13_Still position_20250618-145024.txt created
# processing file 3_Still position_20250618-111255.txt
# label for 3_Still position_20250618-111255.txt created
# processing file 12_Still position_20250618-112436.txt
# label for 12_Still position_20250618-112436.txt created
# processing file 13_Still position_20250618-114029.txt
# label for 13_Still position_20250618-114029.txt created
# processing file 4-3_Still position_20250618-141131.txt
# label for 4-3_Still position_20250618-141131.txt created
# processing file 8_Still position_20250618-114420.txt
# label for 8_Still position_20250618-114420.txt created
# processing file 2-4_Still position_20250618-140706.txt
# label for 2-4_Still position_20250618-140706.txt created
# processing file 3-7-12_Still position_20250618-120705.txt
# label for 3-7-12_Still position_20250618-120705.txt created
# processing file 4-8-12_Still position_20250618-135625.txt
# label for 4-8-12_Still position_20250618-135625.txt created
# processing file 14_Still position_20250618-111131.txt
# label for 14_Still position_20250618-111131.txt created
# processing file 2-8_Still position_20250618-151109.txt
# label for 2-8_Still position_20250618-151109.txt created
# processing file 13-8_Still position_20250618-142153.txt
# label for 13-8_Still position_20250618-142153.txt created
# processing file 7-9_Still position_20250618-140827.txt
# label for 7-9_Still position_20250618-140827.txt created
# processing file 2_Still position_20250618-110517.txt
# label for 2_Still position_20250618-110517.txt created
# processing file 7-9-12-14_Still position_20250618-145324.txt
# label for 7-9-12-14_Still position_20250618-145324.txt created
# processing file 2-4-13_Still position_20250618-120003.txt
# label for 2-4-13_Still position_20250618-120003.txt created
# processing file 2-12-14 _Still position_20250618-115119.txt
# label for 2-12-14 _Still position_20250618-115119.txt created
# processing file 4-9-13_Still position_20250618-135012.txt
# label for 4-9-13_Still position_20250618-135012.txt created
# processing file 2-3-4_Still position_20250618-140525.txt
# label for 2-3-4_Still position_20250618-140525.txt created
# processing file 3-7-9_Still position_20250618-120329.txt
# label for 3-7-9_Still position_20250618-120329.txt created
# processing file 4-9-12-14_Still position_20250618-150045.txt
# label for 4-9-12-14_Still position_20250618-150045.txt created
# processing file 2-7-9-14_Still position_20250618-145452.txt
# label for 2-7-9-14_Still position_20250618-145452.txt created
# processing file 7-12_Still position_20250618-142914.txt
# label for 7-12_Still position_20250618-142914.txt created
# processing file 3_Still position_20250618-114809.txt
# label for 3_Still position_20250618-114809.txt created
# processing file 2-3-7-8_Still position_20250618-150354.txt
# label for 2-3-7-8_Still position_20250618-150354.txt created
# processing file 2--8-14_Still position_20250618-135452.txt
# label for 2--8-14_Still position_20250618-135452.txt created
# processing file 8_Still position_20250618-112157.txt
# label for 8_Still position_20250618-112157.txt created
# processing file 2-4-7-9_Still position_20250618-145155.txt
# label for 2-4-7-9_Still position_20250618-145155.txt created
# processing file 2-3_Still position_20250618-141851.txt
# label for 2-3_Still position_20250618-141851.txt created
# processing file 3-8_Still position_20250618-142025.txt
# label for 3-8_Still position_20250618-142025.txt created
# processing file 9_Still position_20250618-114541.txt
# label for 9_Still position_20250618-114541.txt created
# processing file 4-9-12_Still position_20250618-120530.txt
# label for 4-9-12_Still position_20250618-120530.txt created
# processing file 14_Still position_20250618-112731.txt
# label for 14_Still position_20250618-112731.txt created
# processing file 7-8-9-_Still position_20250618-140354.txt
# label for 7-8-9-_Still position_20250618-140354.txt created
# processing file 2-7-12-14_Still position_20250618-150209.txt
# label for 2-7-12-14_Still position_20250618-150209.txt created
# processing file 4-8_Still position_20250618-143357.txt
# label for 4-8_Still position_20250618-143357.txt created
# processing file 7_Still position_(25045)_20250618-105902.txt
# label for 7_Still position_(25045)_20250618-105902.txt created
# processing file 4-14_Still position_20250618-143220.txt
# label for 4-14_Still position_20250618-143220.txt created
# processing file 9_Still position_20250618-112319.txt
# label for 9_Still position_20250618-112319.txt created
# processing file 3-8-14_Still position_20250618-135318.txt
# label for 3-8-14_Still position_20250618-135318.txt created
# processing file 2-7-12_Still position_20250618-140100.txt
# label for 2-7-12_Still position_20250618-140100.txt created
# processing file 3-8-12_Still position_20250618-135138.txt
# label for 3-8-12_Still position_20250618-135138.txt created
# processing file 2-3-13-14_Still position_20250618-144727.txt
# label for 2-3-13-14_Still position_20250618-144727.txt created
# processing file 4-9_Still position_20250618-143050.txt
# label for 4-9_Still position_20250618-143050.txt created
# processing file 3-8-13_Still position_20250618-135924.txt
# label for 3-8-13_Still position_20250618-135924.txt created
# processing file 3-9-13_Still position_20250618-134723.txt
# label for 3-9-13_Still position_20250618-134723.txt created
# processing file 8_Still position_20250618-110927.txt
# label for 8_Still position_20250618-110927.txt created
# processing file 2-4-12-14_Still position_20250618-144012.txt
# label for 2-4-12-14_Still position_20250618-144012.txt created
# processing file 2-7_Still position_20250618-142749.txt
# label for 2-7_Still position_20250618-142749.txt created
# processing file 4-12-14 _Still position_20250618-115246.txt
# label for 4-12-14 _Still position_20250618-115246.txt created
# processing file 4-14_Still position_20250618-142446.txt
# label for 4-14_Still position_20250618-142446.txt created
# processing file 13_Still position_20250618-112555.txt
# label for 13_Still position_20250618-112555.txt created
# processing file 4_Still position_20250618-114655.txt
# label for 4_Still position_20250618-114655.txt created
# processing file 7_Still position_20250618-110649.txt
# label for 7_Still position_20250618-110649.txt created
# processing file 7-9-13_Still position_20250618-115741.txt
# label for 7-9-13_Still position_20250618-115741.txt created
# processing file 4_Still position_20250618-111410.txt
# label for 4_Still position_20250618-111410.txt created
# processing file 7_Still position_20250618-112028.txt
# label for 7_Still position_20250618-112028.txt created
# processing file 7-8_Still position_20250618-141728.txt
# label for 7-8_Still position_20250618-141728.txt created
# processing file 14-2_Still position_20250618-151512.txt
# label for 14-2_Still position_20250618-151512.txt created
# processing file 7_Still position_20250618-114258.txt
# label for 7_Still position_20250618-114258.txt created
# processing file 13-12_Still position_20250618-141554.txt
# label for 13-12_Still position_20250618-141554.txt created
# processing file 12-14_Still position_20250618-140951.txt
# label for 12-14_Still position_20250618-140951.txt created
# processing file 2-7-13_Still position_20250618-134845.txt
# label for 2-7-13_Still position_20250618-134845.txt created
# processing file 3-4-12-13_Still position_20250618-144608.txt
# label for 3-4-12-13_Still position_20250618-144608.txt created
# processing file 3-12-14_Still position_20250618-120129.txt
# label for 3-12-14_Still position_20250618-120129.txt created
# processing file 12_Still position_20250618-114145.txt
# label for 12_Still position_20250618-114145.txt created
# processing file 4-9-14_Still position_20250618-135759.txt
# label for 4-9-14_Still position_20250618-135759.txt created
# processing file 8-12_Still position_20250618-150939.txt
# label for 8-12_Still position_20250618-150939.txt created
# processing file 8-9_Still position_20250618-141253.txt
# label for 8-9_Still position_20250618-141253.txt created
# processing file 8-9-13-14_Still position_20250618-150804.txt
# label for 8-9-13-14_Still position_20250618-150804.txt created
# processing file 2-12_Still position_20250618-142626.txt
# label for 2-12_Still position_20250618-142626.txt created
# processing file 2_Still position_20250618-114923.txt
# label for 2_Still position_20250618-114923.txt created

# %%
create_dataset_for_FOMO(70)
# Out:
# folder existing but empty
# file 13-14_Still position_20250618-141413_sr250_rx0.npy already processed
# file 7_Still position_20250618-114258_sr250_rx0.npy already processed
# file 3-13_Still position_20250618-142324_sr250_rx0.npy already processed
# file 2-7-9-14_Still position_20250618-145452_sr250_rx0.npy already processed
# file 2-4-9-14_Still position_20250618-145914_sr250_rx0.npy already processed
# file 12_Still position_20250618-112436_sr250_rx0.npy already processed
# file 2_Still position_20250618-114923_sr250_rx0.npy already processed
# file 8-12_Still position_20250618-150939_sr250_rx0.npy already processed
# file 7-12_Still position_20250618-142914_sr250_rx0.npy already processed
# file 2-4-12-14_Still position_20250618-144012_sr250_rx0.npy already processed
# file 4-9-14_Still position_20250618-135759_sr250_rx0.npy already processed
# file 3-12-14_Still position_20250618-120129_sr250_rx0.npy already processed
# file 8_Still position_20250618-110927_sr250_rx0.npy already processed
# file 7-8_Still position_20250618-141728_sr250_rx0.npy already processed
# file 8-14_Still position_20250618-151230_sr250_rx0.npy already processed
# file 7_Still position_20250618-112028_sr250_rx0.npy already processed
# file 3-9-7-13_Still position_20250618-144439_sr250_rx0.npy already processed
# file 3-8-12_Still position_20250618-135138_sr250_rx0.npy already processed
# file 4-9-12_Still position_20250618-120530_sr250_rx0.npy already processed
# file 7-9-13_Still position_20250618-115741_sr250_rx0.npy already processed
# file 7_Still position_(25045)_20250618-105902_sr250_rx0.npy already processed
# file 8_Still position_20250618-112157_sr250_rx0.npy already processed
# file 3-8-14_Still position_20250618-135318_sr250_rx0.npy already processed
# file 7-8-9-_Still position_20250618-140354_sr250_rx0.npy already processed
# file 2-4-7-12_Still position_20250618-145748_sr250_rx0.npy already processed
# file 2-3_Still position_20250618-141851_sr250_rx0.npy already processed
# file 3_Still position_20250618-111255_sr250_rx0.npy already processed
# file 3-8-13_Still position_20250618-135924_sr250_rx0.npy already processed
# file 12-14_Still position_20250618-140951_sr250_rx0.npy already processed
# file 3-4-12-13_Still position_20250618-144608_sr250_rx0.npy already processed
# file 9_Still position_20250618-114541_sr250_rx0.npy already processed
# file 4-2-14 _Still position_20250618-115434_sr250_rx0.npy already processed
# file 4-7-9-12_Still position_20250618-145620_sr250_rx0.npy already processed
# file 8-9_Still position_20250618-141253_sr250_rx0.npy already processed
# file 12-13-14_Still position_20250618-140232_sr250_rx0.npy already processed
# file 4-9_Still position_20250618-143050_sr250_rx0.npy already processed
# file 2--8-14_Still position_20250618-135452_sr250_rx0.npy already processed
# file 12_Still position_20250618-114145_sr250_rx0.npy already processed
# file 4_Still position_20250618-114655_sr250_rx0.npy already processed
# file 14_Still position_20250618-112731_sr250_rx0.npy already processed
# file 2-12-14 _Still position_20250618-115119_sr250_rx0.npy already processed
# file 3-4-13-14_Still position_20250618-144858_sr250_rx0.npy already processed
# file 13_Still position_20250618-114029_sr250_rx0.npy already processed
# file 14-2_Still position_20250618-151512_sr250_rx0.npy already processed
# file 2-8_Still position_20250618-151109_sr250_rx0.npy already processed
# file 4-8_Still position_20250618-143357_sr250_rx0.npy already processed
# file 4-12_Still position_20250618-151352_sr250_rx0.npy already processed
# file 3_Still position_20250618-114809_sr250_rx0.npy already processed
# file 2-7-13_Still position_20250618-134845_sr250_rx0.npy already processed
# file 2-3-4_Still position_20250618-140525_sr250_rx0.npy already processed
# file 4-9-13_Still position_20250618-135012_sr250_rx0.npy already processed
# file 7-9-12-14_Still position_20250618-145324_sr250_rx0.npy already processed
# file 7-9_Still position_20250618-140827_sr250_rx0.npy already processed
# file 2-7_Still position_20250618-142749_sr250_rx0.npy already processed
# file 7-8-12-13_Still position_20250618-150643_sr250_rx0.npy already processed
# file 13-8_Still position_20250618-142153_sr250_rx0.npy already processed
# file 8-9-13-14_Still position_20250618-150804_sr250_rx0.npy already processed
# file 2-12_Still position_20250618-142626_sr250_rx0.npy already processed
# file 14_Still position_20250618-111131_sr250_rx0.npy already processed
# file 2-4-13_Still position_20250618-120003_sr250_rx0.npy already processed
# file 3-8_Still position_20250618-142025_sr250_rx0.npy already processed
# file 2-4_Still position_20250618-140706_sr250_rx0.npy already processed
# file 3-9-13_Still position_20250618-134723_sr250_rx0.npy already processed
# file 3-7-12_Still position_20250618-120705_sr250_rx0.npy already processed
# file 9_Still position_20250618-112319_sr250_rx0.npy already processed
# file 4-14_Still position_20250618-142446_sr250_rx0.npy already processed
# file 2-7-12-14_Still position_20250618-150209_sr250_rx0.npy already processed
# file 2-4-7-9_Still position_20250618-145155_sr250_rx0.npy already processed
# file 7_Still position_20250618-110649_sr250_rx0.npy already processed
# file 2-4-12_Still position_20250618-115616_sr250_rx0.npy already processed
#
# --- Loading and processing data for beamforming: 3-7-9_Still position_20250618-120329_sr250_rx0.npy ---
# Processing 3-7-9_Still position_20250618-120329_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 3-7-9_Still position_20250618-120329_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 3-7-9_Still position_20250618-120329_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 3-7-9_Still position_20250618-120329
#
# --- Loading and processing data for beamforming: 13-12_Still position_20250618-141554_sr250_rx0.npy ---
# Processing 13-12_Still position_20250618-141554_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 13-12_Still position_20250618-141554_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 13-12_Still position_20250618-141554_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 13-12_Still position_20250618-141554
#
# --- Loading and processing data for beamforming: 3-7-13_Still position_20250618-120843_sr250_rx0.npy ---
# Processing 3-7-13_Still position_20250618-120843_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 3-7-13_Still position_20250618-120843_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 3-7-13_Still position_20250618-120843_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 3-7-13_Still position_20250618-120843
#
# --- Loading and processing data for beamforming: 4_Still position_20250618-111410_sr250_rx0.npy ---
# Processing 4_Still position_20250618-111410_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4_Still position_20250618-111410_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4_Still position_20250618-111410_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 4_Still position_20250618-111410
#
# --- Loading and processing data for beamforming: 4-12-14 _Still position_20250618-115246_sr250_rx0.npy ---
# Processing 4-12-14 _Still position_20250618-115246_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-12-14 _Still position_20250618-115246_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-12-14 _Still position_20250618-115246_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 4-12-14 _Still position_20250618-115246
#
# --- Loading and processing data for beamforming: 2-3-13-14_Still position_20250618-144727_sr250_rx0.npy ---
# Processing 2-3-13-14_Still position_20250618-144727_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2-3-13-14_Still position_20250618-144727_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2-3-13-14_Still position_20250618-144727_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 2-3-13-14_Still position_20250618-144727
#
# --- Loading and processing data for beamforming: 14_Still position_20250618-113914_sr250_rx0.npy ---
# Processing 14_Still position_20250618-113914_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 14_Still position_20250618-113914_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 14_Still position_20250618-113914_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 14_Still position_20250618-113914
#
# --- Loading and processing data for beamforming: 2-7-12_Still position_20250618-140100_sr250_rx0.npy ---
# Processing 2-7-12_Still position_20250618-140100_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2-7-12_Still position_20250618-140100_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2-7-12_Still position_20250618-140100_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 2-7-12_Still position_20250618-140100
#
# --- Loading and processing data for beamforming: 3-4-8-9_Still position_20250618-150521_sr250_rx0.npy ---
# Processing 3-4-8-9_Still position_20250618-150521_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 3-4-8-9_Still position_20250618-150521_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 3-4-8-9_Still position_20250618-150521_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 3-4-8-9_Still position_20250618-150521
#
# --- Loading and processing data for beamforming: 13_Still position_20250618-112555_sr250_rx0.npy ---
# Processing 13_Still position_20250618-112555_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 13_Still position_20250618-112555_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 13_Still position_20250618-112555_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 13_Still position_20250618-112555
#
# --- Loading and processing data for beamforming: 8_Still position_20250618-114420_sr250_rx0.npy ---
# Processing 8_Still position_20250618-114420_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 8_Still position_20250618-114420_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 8_Still position_20250618-114420_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 8_Still position_20250618-114420
#
# --- Loading and processing data for beamforming: 4-3_Still position_20250618-141131_sr250_rx0.npy ---
# Processing 4-3_Still position_20250618-141131_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-3_Still position_20250618-141131_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-3_Still position_20250618-141131_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 4-3_Still position_20250618-141131
#
# --- Loading and processing data for beamforming: 4-8-12_Still position_20250618-135625_sr250_rx0.npy ---
# Processing 4-8-12_Still position_20250618-135625_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-8-12_Still position_20250618-135625_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-8-12_Still position_20250618-135625_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 4-8-12_Still position_20250618-135625
#
# --- Loading and processing data for beamforming: 2_Still position_20250618-110517_sr250_rx0.npy ---
# Processing 2_Still position_20250618-110517_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2_Still position_20250618-110517_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2_Still position_20250618-110517_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 2_Still position_20250618-110517
#
# --- Loading and processing data for beamforming: 4-14_Still position_20250618-143220_sr250_rx0.npy ---
# Processing 4-14_Still position_20250618-143220_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-14_Still position_20250618-143220_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-14_Still position_20250618-143220_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 4-14_Still position_20250618-143220
#
# --- Loading and processing data for beamforming: 2-3-12-13_Still position_20250618-145024_sr250_rx0.npy ---
# Processing 2-3-12-13_Still position_20250618-145024_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2-3-12-13_Still position_20250618-145024_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2-3-12-13_Still position_20250618-145024_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 2-3-12-13_Still position_20250618-145024
#
# --- Loading and processing data for beamforming: 2-3-7-8_Still position_20250618-150354_sr250_rx0.npy ---
# Processing 2-3-7-8_Still position_20250618-150354_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2-3-7-8_Still position_20250618-150354_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 2-3-7-8_Still position_20250618-150354_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 2-3-7-8_Still position_20250618-150354
#
# --- Loading and processing data for beamforming: 4-9-12-14_Still position_20250618-150045_sr250_rx0.npy ---
# Processing 4-9-12-14_Still position_20250618-150045_sr250_rx0.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-9-12-14_Still position_20250618-150045_sr250_rx1.npy...
# Shape of the decluttered results:  (1200, 50)
# Processing 4-9-12-14_Still position_20250618-150045_sr250_rx2.npy...
# Shape of the decluttered results:  (1200, 50)
# Performing azimuth beamforming using RX0 and RX1 data...
# Shape of the first antenna: (1200, 45), with dtype complex64
# Shape of the second antenna: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Shape of the beamformed data: (1200, 45, 46) with dtype complex128
# .png saved as 4-9-12-14_Still position_20250618-150045

# %%
import json

output_data = {
    "version": 1,
    "type": "bounding-box-labels",
    "boundingBoxes": {}
}
dir_path = "/kaggle/working/"
for file in os.listdir(dir_path):
    if ".txt" in file:
        ids= file.split('_')[0]
        ids=ids.split('-')
        ids=[id for id in ids]
        label_file_path = os.path.join(dir_path, file)

        file=file.replace(".txt",".png")
        image_path= os.path.join("/kaggle/input/complete-dataset/dataset_FOMO", file)
        with Image.open(image_path) as img:
            img_width, img_height = img.size
            
        with open(label_file_path, 'r') as label:
            boxes_for_this_image = []
            id_num=0
            for line in label:
                parts = line.strip().split()
                #print(parts)
                x_center_norm = float(parts[1])
                y_center_norm = float(parts[2])
                width_norm = float(parts[3])
                height_norm = float(parts[4])
                
                box_w = width_norm * img_width
                box_h = height_norm * img_height
                box_x = (x_center_norm * img_width) - (box_w / 2)
                box_y = (y_center_norm * img_height) - (box_h / 2)

                box = {
                        "label": ids[id_num],
                        "x": box_x,
                        "y": box_y,
                        "width": box_w,
                        "height": box_h
                    }
                id_num+=1
                boxes_for_this_image.append(box)
            if boxes_for_this_image:
                file= file.replace(".txt",".png")
                output_data["boundingBoxes"][file] = boxes_for_this_image

# Salva il file JSON finale
output_file_path = os.path.join(dir_path, 'bounding_boxes.labels')
with open(output_file_path, 'w') as f:
    json.dump(output_data, f, indent=2)
# Out:
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:3442: DecompressionBombWarning: Image size (92160000 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(

# %%
for file in os.listdir(dir_path):
    if ".txt" in file:
        file_path= os.path.join(dir_path,file)
        os.remove(file_path)

# %%
# !zip -r partial.zip /kaggle/working/dataset_FOMO
# Out:
#   adding: kaggle/working/dataset_FOMO/ (stored 0%)
#   adding: kaggle/working/dataset_FOMO/2-3-7-8_Still position_20250618-150354.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/4_Still position_20250618-111410.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/4-3_Still position_20250618-141131.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/2-3-13-14_Still position_20250618-144727.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/4-8-12_Still position_20250618-135625.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/13-12_Still position_20250618-141554.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/13_Still position_20250618-112555.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/3-7-13_Still position_20250618-120843.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/3-4-8-9_Still position_20250618-150521.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/2-7-12_Still position_20250618-140100.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/14_Still position_20250618-113914.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/4-9-12-14_Still position_20250618-150045.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/2_Still position_20250618-110517.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/2-3-12-13_Still position_20250618-145024.png (deflated 98%)
#   adding: kaggle/working/dataset_FOMO/4-12-14 _Still position_20250618-115246.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/8_Still position_20250618-114420.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/4-14_Still position_20250618-143220.png (deflated 97%)
#   adding: kaggle/working/dataset_FOMO/3-7-9_Still position_20250618-120329.png (deflated 97%)

# %%
#if create_label_from_png("/kaggle/working/dataset_FOMO/14_Still position_20250618-112731.png","/kaggle/working/label_14_still_position.txt"):
    #print("label created")
visualize_sample(filename="14_Still position_20250618-112731.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_36/244696833.py in <cell line: 0>()
#       1 #if create_label_from_png("/kaggle/working/dataset_FOMO/14_Still position_20250618-112731.png","/kaggle/working/label_14_still_position.txt"):
#       2     #print("label created")
# ----> 3 visualize_sample(filename="14_Still position_20250618-112731.png")
#
# NameError: name 'visualize_sample' is not defined

# %%
#if create_fomo_label("(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004.png","/kaggle/working/dataset_FOMO/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004.txt"):
 #   print("label created")
visualize_sample(filename="8-9-13-14_Still position_20250618-150804.png")
# Out:
# Visualizzazione del campione: 8-9-13-14_Still position_20250618-150804.png
# Trovate e disegnate 8 etichette.

# %%
def doppler_processing(data, prf, window_fn=np.hanning):
    """
    Perform Doppler FFT along time axis of beamformed radar data.

    Parameters:
        data : np.ndarray
            Complex beamformed data, shape (time_frames, range_bins, angle_bins)
        prf : float
            Pulse Repetition Frequency (Hz)
        window_fn : callable
            Window function to reduce sidelobes, default: np.hanning

    Returns:
        doppler_cube : np.ndarray
            Doppler spectrum cube, shape (doppler_bins, range_bins, angle_bins)
        doppler_freqs : np.ndarray
            Doppler frequency bins (Hz), shape (doppler_bins,)
    """
    time_frames = data.shape[0]
    
    # Apply window to time axis to reduce sidelobes
    window = window_fn(time_frames).reshape(-1, 1, 1)
    windowed_data = data * window

    # Doppler FFT along time axis
    doppler_cube = np.fft.fftshift(
        np.fft.fft(windowed_data, axis=0), 
        axes=0
    )

    # Normalize magnitude
    doppler_cube = np.abs(doppler_cube)

    # Compute Doppler frequency bins
    doppler_freqs = np.fft.fftshift(
        np.fft.fftfreq(time_frames, d=1.0/prf)
    )

    return doppler_cube, doppler_freqs

# %%
 #trying to aggregate by summing magnitudes for moving file

if beamformed_3d_data is not None:
    for i in range(4, 0, -1):
        target_time_frame = round(beamformed_3d_data.shape[0] / i)
        # doppler 
        doppler_data, _ = doppler_processing(beamformed_3d_data, prf=f)
        aggregated_beamformed_data = np.max(doppler_data[:target_time_frame + 1, :,],axis=0)
        #aggregated_beamformed_data = np.sum(np.abs(beamformed_3d_data[:target_time_frame + 1, :,]),axis=0)
        # Normalization
        normalized_beamformed_data = normalize_range_angle_map(aggregated_beamformed_data)
        title = f"Beamforming ({target_time_frame} time frames) - {os.path.basename(base_file_for_beamforming).replace('_sr250_rx0.npy', '')}"
        #show_range_angle_plot(normalized_beamformed_data, beam_steering_angles, title)
else:
    print("Beamforming could not be completed.")
