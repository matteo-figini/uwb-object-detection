# %% [markdown]
# # SR250 UWB (Ultra-Wide Band) Radar Visualisation and Digital Beamforming
# # Comprehensive Notebook
#
# In this notebook, we are going to extract the data from a dataset containing .npy files, which are the dataset collection of an UWB (Ultra-Wide Band) Radar, apply beamforming and then doing object detection.

# %% [markdown]
# ## 1. Import required libraries
# All necessary libraries from the original notebooks are imported here.

# %%
# Import required libraries
import numpy as np
import matplotlib.pyplot as plt
import os
import re
from PIL import Image
import matplotlib.patches as patches
from typing import Optional, List, Tuple
import json
import random
import gc # Garbage Collection

# %% [markdown]
# ## 2. Global Radar Parameters
# These parameters define the physical characteristics of the UWB radar system. They are consistent across all processing tasks.

# %%
# --- Radar Parameters ---
d = 1.75e-2          # Distance between rx antenna elements for azimuth (m)
f = 7.987e9          # Center frequency of radar pulse (Hz) -> 7.737 - 8.237 GHz
c = 299792458        # Speed of light (m/s)

l = c / f            # Wavelength (m)
k = 2 * np.pi / l    # Wavenumber (rad/m)

# General beam steering angles range (num_angles will vary per task)
min_angle_deg = -45
max_angle_deg = 45

# %% [markdown]
# ## 3. Decluttering
#
# ### 3.1 Decluttering with Simple Moving Average
#
# The function `decluttering_ma` implements a **Simple Moving Average** (SMA) for background estimation, as described in the Repole's thesis. This is a **Finite Impulse Response (FIR) filter**, meaning its current output only depends on a fixed, finite number of recent past inputs (defined by W).
#
# Formula: $\tilde{s}_{n,m}[k] = s_{n,m}[k] - \frac{1}{W} * \sum_{i = m-W+1}^{m}(s_{n,i}[k]) $
#
# The output for the first $W-1$ frames is set to zero because a full W-sized window is not yet available to compute the average background. For each frame $m$ (starting from W-1), it calculates the average of the current frame and the preceding W-1 frames.
#
# W is the window size: it defines the exact number of frames (current + W-1 previous) that are averaged to form the background estimate for that specific point in time.
# The decluttered output for the current frame is calculated subtracting the current radar frame `cirs[m, :]` from the window_average.
#
# **Characteristics**:
# * *Fixed Window*: The background estimate is always based on a precise, fixed number of the most recent frames.
# * *Abrupt Adaptation*: If a new static object enters the scene, it will cause a strong "ghost" signal for exactly W frames, after which it will be fully incorporated into the background average and suppressed. Similarly, if an object leaves, it will "ghost" for W frames.
# * *Memory*: Requires access to (or storage of) the W most recent frames.
# * *Risk of Target Suppression*: If a target moves very slowly or stops for a duration longer than W frames, it will be included in the window_average and thus suppressed.

# %%
def decluttering_ma(cirs: np.ndarray, W: int) -> np.ndarray:
    """
    Performs decluttering on the time series of CIRs using a moving average
    background subtraction method, as described in Equation (9) of the thesis.

    The decluttered signal s_hat_n,m[k] is calculated as:
    s_hat_n,m[k] = s_n,m[k] - (1/W) * sum(s_n,i[k] for i from m-W+1 to m)

    Args:
        cirs (np.ndarray): Input radar data matrix of shape (time_frames, range_bins),
                           containing complex data.
        W (int): The window dimension (number of subsequent radar frames)
                 to be considered for the moving average. W must be >= 1.

    Returns:
        np.ndarray: The decluttered radar data matrix of the same shape as cirs,
                    containing complex data. The first (W-1) frames will be zeros.
    """
    if cirs.shape[0] == 0:
        return cirs
    
    if not isinstance(W, int) or W < 1:
        raise ValueError("Window size 'W' must be an integer and W >= 1.")

    num_frames, num_range_bins = cirs.shape
    result = np.zeros_like(cirs, dtype=np.complex64)

    # Loop from the (W-1)-th frame (0-indexed) onwards,
    # as this is the first frame for which a full 'W'-sized window is available.
    for m in range(W - 1, num_frames):
        # Define the window: from (m - W + 1) up to and including m
        window_average = np.mean(cirs[m - W + 1 : m + 1, :], axis=0)
        
        # Apply the subtraction formula: current_frame - window_average
        result[m, :] = cirs[m, :] - window_average
        
    return result

# %% [markdown]
# ### 3.2 Decluttering with Exponential Moving Average
#
# The function `decluttering_ewma` implements an **Exponential Moving Average (EWMA)** for background estimation. It's an **Infinite Impulse Response (IIR) filter**, meaning its current output depends on all past inputs, though older inputs have exponentially decreasing influence.
#
# In the initialization, the *dec_base* (background estimate) is initialized with the very first radar frame (`cirs[0, :]`). The output for the first frame is set to zero.
#
# For each subsequent frame i, the dec_base is updated using the formula:
# `dec_base = dec_base * alpha + cirs[i, :] * (1 - alpha)`
#
# alpha is the "forgetting factor" or "smoothing factor." A high alpha means the dec_base retains a large percentage (alpha) of its previous value and incorporates a small percentage (1 - alpha) of the current frame. This makes the background estimate adapt slowly to changes but remain very stable for static clutter.
#
# The decluttered output for the current frame is calculated as:
# `result[i, :] = (cirs[i, :] - dec_base) * normalization`
# The current radar frame `cirs[i, :]` is subtracted from the continuously updated dec_base. Static clutter, being present in both, will largely cancel out. Moving targets, being absent from dec_base, will remain.
#
# **normalization** is a scaling factor applied to match a specific output scale (as per the original logger's logic).
#
# **Characteristics**:
# * *Adaptive*: The background estimate continuously adapts to changes.
# * *Smooth Adaptation*: Changes in the background are incorporated smoothly and exponentially.
# * *Memory Efficient*: Only needs to store the previous dec_base, not a buffer of past frames.
# * *Good for Stable Clutter*: Very effective for suppressing truly static and consistent clutter over long periods.
# * *"Ghosting"*: If a new static object appears, it will create a "ghost" signal for a while until it is slowly absorbed into the dec_base. The duration of this ghosting depends on alpha.

# %%
def decluttering_ewma (cirs: np.ndarray, alpha: float = 0.9) -> np.ndarray:
    """
    Performs decluttering on the time series of CIRs using Exponential Moving Average.
    Matches the logic of decluttering_alt in the Logger class from original context.

    Args:
        cirs (np.ndarray): Input radar data matrix of shape (time_frames, range_bins),
                           containing complex data.
        alpha (float): The smoothing factor (0 to 1). Higher alpha means slower adaptation.

    Returns:
        np.ndarray: The decluttered radar data matrix of the same shape as cirs,
                    containing complex data. The first frame's output is zeros.
    """
    if cirs.shape[0] == 0:
        return cirs
        
    # 1. Initialise the background (`dec_base`) with the data from the FIRST frame.
    dec_base = cirs[0, :].astype(np.complex64)
    
    # 2. Create an empty result matrix.
    result = np.zeros_like(cirs, dtype=np.complex64)
    
    # 3. The first frame's output is always zero, as per logger.py's logic.
    normalization = (1 + alpha) / 2

    # 4. Loop from the SECOND frame (index 1) onwards.
    for i in range(1, cirs.shape[0]):
        # Calculate the output using the background from the *previous* step
        result[i, :] = (cirs[i, :] - dec_base) * normalization
        
        # Update the background for the *next* iteration
        dec_base = dec_base * alpha + cirs[i, :] * (1 - alpha)
        
    return result

# %% [markdown]
# ## 4. Helper Functions for Radar Data Processing
# This section contains helper functions for loading, preprocessing, and beamforming radar data.
#
# ### 4.1 Load and Declutter Single Antenna File (Internal Helper)
# This helper function loads a single .npy file, applies the specified decluttering method, and is used internally by _get_all_decluttered_complex_data.

# %%
def _load_and_declutter_single_file(
    filename: str
) -> Optional[np.ndarray]:
    """
    Loads and declutters a single SR250 antenna file using a specified method.

    Args:
        filename (str): The full path to the .npy file.
        declutter_method (str): 'ma' for Moving Average or 'ewma' for Exponential Moving Average.
        declutter_param (float): 'W' (window size) for 'ma', or 'alpha' (smoothing factor) for 'ewma'.

    Returns:
        np.ndarray: The decluttered radar data matrix (complex data), or None if file not found.
    """
    if not os.path.exists(filename):
        print(f"Warning: File not found, skipping: {filename}")
        return None

    raw_frames = np.load(filename)  # (time, range_bins)
    # raw_frames = raw_frames[:, :50] # Keep only the first 50 bins

    decluttered_matrix = decluttering_ewma(raw_frames, alpha=0.9)
    decluttered_matrix = decluttering_ma(decluttered_matrix, 20)

    # if declutter_method == 'ma':
    #    decluttered_matrix = decluttering_ma(raw_frames, int(declutter_param))
    # elif declutter_method == 'ewma':
    #    decluttered_matrix = decluttering_ewma(raw_frames, alpha=declutter_param)
    # else:
    #    raise ValueError(f"Unknown decluttering method: {declutter_method}")
    
    return decluttered_matrix

# %% [markdown]
# ### 4.2 Get All Decluttered Complex Data for Antennas
# This function orchestrates the loading and decluttering for all three radar antennas (RX0, RX1, RX2) for a given base filename. It also handles the removal of initial stabilization frames and optionally displays a time-distance plot.

# %%
def _get_all_decluttered_complex_data(
    base_filename: str,
    stabilization_frames_to_remove: int,
    display_time_distance_plot: bool = False
) -> List[np.ndarray]:
    """
    Loads and declutters SR250 data from antennas RX0 and RX2
    Removes initial stabilization frames. Optionally displays a mean time-distance plot.

    Args:
        base_filename (str): The full path to the '_sr250_rx0.npy' file (used to infer RX1, RX2 paths).
        declutter_method (str): 'ma' for Moving Average or 'ewma' for Exponential Moving Average.
        declutter_param (float): 'W' (window size) for 'ma', or 'alpha' (smoothing factor) for 'ewma'.
        stabilization_frames_to_remove (int): Number of initial frames to remove after decluttering.
        display_time_distance_plot (bool): If True, computes and displays a mean time-distance plot.

    Returns:
        List[np.ndarray]: A list of decluttered complex data matrices, one for each antenna.
                          Returns an empty list if processing fails.
    """
    file_list = []
    if "_sr250_rx0" in base_filename:
        base_path = base_filename.replace("_sr250_rx0.npy", "")
        file_list.append(f"{base_path}_sr250_rx0.npy")
        file_list.append(f"{base_path}_sr250_rx2.npy")
    else:
        print("Error: Please provide the path to an 'sr250_rx0' file.")
        return []

    all_decluttered_complex = []
    all_magnitudes_for_plot = []

    print(f"Processing antenna files for '{os.path.basename(base_filename)}'...")
    for f in file_list:
        decluttered_result = _load_and_declutter_single_file(f)
        if decluttered_result is not None:
            # Remove stabilization frames AFTER decluttering
            final_decluttered_data = decluttered_result[stabilization_frames_to_remove:, :]
            all_decluttered_complex.append(final_decluttered_data)
            if display_time_distance_plot:
                all_magnitudes_for_plot.append(np.abs(final_decluttered_data))
            print(f"  {os.path.basename(f)} processed. Shape after decluttering and frame removal: {final_decluttered_data.shape}")
        else:
            print(f"  Skipping {f} due to loading/decluttering issue.")

    if not all_decluttered_complex:
        print("Error: No data was processed for any antenna. Returning empty list.")
        return []

    if display_time_distance_plot:
        if all_magnitudes_for_plot:
            combined_magnitude_matrix = np.mean(np.stack(all_magnitudes_for_plot, axis=0), axis=0)
            show_time_distance_plot(combined_magnitude_matrix, f"SR250 UWB Time-Distance Heatmap - Mean of All Antennas ({os.path.basename(base_filename).replace('_sr250_rx0.npy', '')})")
        else:
            print("  No magnitude data available to display time-distance plot.")

    return all_decluttered_complex

# %% [markdown]
# ### 4.3 Compute Beamforming Weights
# Calculates the complex weights required for digital beamforming, based on the array geometry and desired steering angles.

# %%
def compute_bf_weights(angle_range_rad: np.ndarray, delta: float, k_wavenumber: float, num_rx_elements: int) -> np.ndarray:
    """
    Computes beamforming weights for a linear array.
    
    Args:
        angle_range_rad (np.ndarray): Array of angles (in radians) for which to compute weights.
        delta (float): Distance between adjacent antenna elements.
        k_wavenumber (float): Wavenumber (2*pi/lambda).
        num_rx_elements (int): Number of receive antenna elements.
        
    Returns:
        np.ndarray: Beamforming weights of shape (len(angle_range_rad), num_rx_elements).
    """
    bf_weights = np.zeros((angle_range_rad.shape[0], num_rx_elements), dtype="complex")
    for i in range(angle_range_rad.shape[0]):      # Loop over angles
        for j in range(num_rx_elements):       # Loop over antenna elements
            # Phase shift for element j at angle_range_rad[i]
            bf_weights[i, j] = np.exp(-1j * k_wavenumber * delta * j * np.sin(angle_range_rad[i]))
    return bf_weights

# %% [markdown]
# ### 4.4 Perform Azimuth Beamforming
# Applies the computed beamforming weights to the complex radar data from two antennas (RX0 and RX2) to produce a Range-Azimuth map over time.

# %%
def perform_azimuth_beamforming(
    rx0_complex_data: np.ndarray,
    rx1_complex_data: np.ndarray, 
    d_spacing: float,
    k_wavenumber: float,
    beam_steering_angles_rad: np.ndarray
) -> Optional[np.ndarray]:
    """
    Performs azimuth beamforming on complex data from two antennas.
    This version processes all time frames individually, producing a 3D output.
    The input `rx1_complex_data` is intended to be the data from the second antenna used
    for beamforming (e.g., RX2 when RX0 is the first).

    Args:
        rx0_complex_data (np.ndarray): Complex CIRs from the first antenna (time_frames, range_bins).
        rx1_complex_data (np.ndarray): Complex CIRs from the second antenna (time_frames, range_bins).
        d_spacing (float): Distance between the two RX antennas (element spacing).
        k_wavenumber (float): Wavenumber (2*pi/lambda).
        beam_steering_angles_rad (np.ndarray): Array of angles in radians for beamsteering.

    Returns:
        np.ndarray: Beamformed data of shape (time_frames, range_bins, angles), or None if error.
    """
    # Resize the range bins due to slight mismatch, as observed in original notebooks
    # This assumes rx0 is the "reference" and rx1 is the "second" antenna (e.g. RX2 from file_list)
    rx0_cropped = rx0_complex_data[:, 0:45]
    rx1_cropped = rx1_complex_data[:, 2:47] # Shifted by 2 bins relative to rx0_cropped

    if rx0_cropped is None or rx1_cropped is None:
        print("Error: Input data for beamforming is missing.")
        return None
    if rx0_cropped.shape != rx1_cropped.shape:
        print(f"Error: Antenna data shapes do not match after cropping: {rx0_cropped.shape} vs {rx1_cropped.shape}. Cannot perform beamforming.")
        return None
    else:
        print(f"Shape of the antennas data after cropping: {rx0_cropped.shape}, with dtype {rx0_cropped.dtype}")
    
    num_time_frames = rx0_cropped.shape[0]   # Slow time
    num_range_bins = rx0_cropped.shape[1]    # Fast time
    num_rx_elements = 2 # Always 2 antennas for azimuth beamforming
    num_angles = beam_steering_angles_rad.shape[0]

    # Compute beamforming weights. These are constant for all time frames and range bins.
    bf_weights = compute_bf_weights(beam_steering_angles_rad, d_spacing, k_wavenumber, num_rx_elements)

    # Initialize a 3D array to store beamformed results
    beamformed_3d_result = np.zeros((num_time_frames, num_range_bins, num_angles), dtype=complex)
    print(f"Starting beamforming over {num_time_frames} time frames and {num_range_bins} range bins...")

    # This version exploits NumPy vectorized operations for efficiency.
    for t in range(num_time_frames):
        # Stack complex CIRs for the current time frame from both RX antennas
        # data_for_current_frame_all_bins will have shape (num_rx_elements, range_bins)
        data_for_current_frame_all_bins = np.stack([rx0_cropped[t, :], rx1_cropped[t, :]], axis=0) # [2], [4]

        # Perform matrix multiplication for all range bins in the current frame simultaneously
        # (num_angles, num_rx_elements) @ (num_rx_elements, num_range_bins)
        # Result of dot product: (num_angles, num_range_bins)
        beamformed_slice_transposed = np.dot(bf_weights, data_for_current_frame_all_bins)
        
        # Transpose the result to get (range_bins, angles) for this time slice
        beamformed_3d_result[t, :, :] = beamformed_slice_transposed.T
            
    print("Beamforming complete for all frames and range bins.")
    return beamformed_3d_result

# %% [markdown]
# ### 4.5 Normalize Range-Angle Map
# Normalizes a 2D Range-Angle map to the range [1] using min-max scaling, as described in Equation (11) of the thesis.

# %%
def normalize_range_angle_map(matrix: np.ndarray) -> np.ndarray:
    """
    Normalizes a 2D Range-Angle map to the range [0, 1] using min-max scaling.

    Args:
        matrix (np.ndarray): The input 2D Range-Angle map.

    Returns:
        np.ndarray: The normalized map.
    """
    min_val = np.min(matrix)
    max_val = np.max(matrix)
    if max_val == min_val: # Avoid division by zero for uniform matrices
        return np.zeros_like(matrix)
    normalized_matrix = (matrix - min_val) / (max_val - min_val)
    return normalized_matrix

# %% [markdown]
# ### 4.6 Show Time-Distance Plot
# Visualizes the magnitude of radar data over time and distance as a heatmap.

# %%
def show_time_distance_plot(matrix: np.ndarray, title: str = "SR250 UWB Time-Distance Heatmap"):
    """
    Visualizes the time-distance (heatmap) of radar data magnitude.

    Args:
        matrix (np.ndarray): The input matrix (time_frames, range_bins).
        title (str): Title for the plot.
    """
    # The matrix shape is already (time, distance). We need to transpose for plotting
    # so that distance is on Y-axis and time on X-axis.
    heatmap_data = matrix.T

    fig, ax = plt.subplots(figsize=(12, 5))
    im = ax.imshow(
        heatmap_data, 
        aspect='auto', 
        origin='lower', # Origin lower for distance on Y-axis (0 at bottom)
        cmap='gist_gray',
        interpolation='nearest',
        vmin=np.min(heatmap_data),
        vmax=np.percentile(heatmap_data, 99) # Use 99th percentile for better contrast
    )

    ax.set_title(title)
    ax.set_xlabel("Time (Frame Number)")
    ax.set_ylabel("Distance (Range Bin)")
    fig.colorbar(im, ax=ax, label="Average Signal Magnitude")
    
    plt.tight_layout()
    plt.show()
    plt.close(fig) # Close the figure to free up memory

# %% [markdown]
# ### 4.7 Plot Range-Angle Heatmap (Flexible Helper)
# A flexible plotting function for beamformed Range-Azimuth maps. It can save to a file, display on screen, and highlight ground truth positions.
# Refactoring Note: This function replaces show_range_angle_plot from the original notebooks, combining their functionalities and adding more control.

# %%
def _plot_range_angle_heatmap(
    matrix: np.ndarray,
    angles_rad: np.ndarray,
    title: str = "Beamformed Range-Azimuth Image",
    range_conversion_factor: int = 10,
    output_dir: Optional[str] = None, # If provided, saves to this directory
    show_plot: bool = True, # If True, calls plt.show()
    gt_highlight_coords_list: Optional[List[Tuple[int, int]]] = None,
    image_width_px: Optional[int] = None, # For OD dataset specific saved image width
    image_height_px: Optional[int] = None # For OD dataset specific saved image height
) -> Optional[str]:
    """
    Visualizes the beamformed data as a 2D heatmap (Distance vs. Azimuth Angle).
    Converts range bins to meters for visualization.
    Optionally draws cross markers at specified ground truth positions.
    Can save the image to a file and/or display it.

    Args:
        matrix (np.ndarray): The beamformed data, shape (range_bins, angles).
                             This should be the magnitude for plotting.
        angles_rad (np.ndarray): Array of angles in radians used for beamsteering.
        title (str): Title for the plot.
        range_conversion_factor (int/float): Number of bins per meter.
        output_dir (Optional[str]): Directory to save the image. If None, image is not saved.
        show_plot (bool): If True, displays the plot using plt.show().
        gt_highlight_coords_list (Optional[List[Tuple[int, int]]]): A list of (range_bin_idx, angle_idx) tuples
                                                           to draw cross markers on the heatmap.
        image_width_px (Optional[int]): Target width in pixels for saved image.
        image_height_px (Optional[int]): Target height in pixels for saved image.

    Returns:
        Optional[str]: The filename of the saved image if `output_dir` is provided, otherwise None.
    """
    
    # print("Generating Beamformed plot...")

    heatmap_data = matrix
    
    # Calculate figsize to match target pixel dimensions if provided for saving.
    # Otherwise, use a default display size.
    dpi_for_save = 100 # Consistent DPI for saving
    if output_dir and image_width_px and image_height_px:
        # figsize = pixels / dpi
        fig, ax = plt.subplots(figsize=(2, 2))
    else:
        fig, ax = plt.subplots(figsize=(12, 5)) # Default size for display
    
    angles_deg = np.rad2deg(angles_rad)

    min_range_meters = 0
    max_range_meters = heatmap_data.shape[0] / range_conversion_factor

    extent = [angles_deg.min(), angles_deg.max(), min_range_meters, max_range_meters] 

    im = ax.imshow(
        heatmap_data, 
        aspect='auto', 
        origin='lower', 
        cmap='gist_gray',
        interpolation='nearest',
        vmin=np.min(heatmap_data),
        vmax=np.max(heatmap_data),
        extent=extent 
    )
    
    # --- Add cross markers for ground truth positions if provided ---
    if gt_highlight_coords_list:
        for i, (r_idx, a_idx) in enumerate(gt_highlight_coords_list):
            # Convert range_bin_idx to meters and angle_idx to degrees for plotting
            plot_y_meters = r_idx / range_conversion_factor
            plot_x_degrees = np.rad2deg(angles_rad[a_idx])
            label_text = 'Ground Truth Position' if i == 0 else None
            ax.scatter(plot_x_degrees, plot_y_meters, marker='x', color='red', s=200, linewidth=3, label=label_text)
        if gt_highlight_coords_list:
            ax.legend()
    
    saved_filename = None
    if output_dir:
        image_filename = f"{title}.png"
        full_output_path = os.path.join(output_dir, image_filename)
        os.makedirs(output_dir, exist_ok=True) # Ensure the directory exists
        
        # Turn off axes for clean image saving if specific pixel dimensions are requested
        if image_width_px and image_height_px:
             ax.axis('off')
             try:
                 fig.savefig(full_output_path, bbox_inches='tight', pad_inches=0, dpi=dpi_for_save)
                 print(f"Image saved successfully to: {full_output_path}")
                 saved_filename = image_filename
             except Exception as e:
                 print(f"Error saving image to {full_output_path}: {e}")
        else: # For general saving without specific pixel constraints, keep axes on
            try:
                fig.savefig(full_output_path, bbox_inches='tight', dpi=dpi_for_save)
                print(f"Image saved successfully to: {full_output_path}")
                saved_filename = image_filename
            except Exception as e:
                print(f"Error saving image to {full_output_path}: {e}")
    
    if show_plot:
        ax.axis('on') # Ensure axes are on if showing, even if turned off for saving
        ax.set_title(title)
        ax.set_xlabel("Azimuth Angle (degrees)")
        ax.set_ylabel("Distance (meters)")
        fig.colorbar(im, ax=ax, label="Beamformed Signal Magnitude")
        
        num_ticks_x = 7 
        tick_indices_x = np.linspace(0, len(angles_deg) - 1, num_ticks_x).astype(int)
        ax.set_xticks(angles_deg[tick_indices_x])
        ax.set_xticklabels([f"{a:.0f}°" for a in angles_deg[tick_indices_x]])

        if max_range_meters <= 1:
            y_tick_interval = 0.1
        elif max_range_meters <= 5:
            y_tick_interval = 0.5
        else:
            y_tick_interval = 1.0
        
        y_ticks = np.arange(min_range_meters, max_range_meters + y_tick_interval, y_tick_interval)
        ax.set_yticks(y_ticks)
        ax.set_yticklabels([f"{d:.1f}m" for d in y_ticks])
        
        plt.tight_layout()
        plt.show()
    
    plt.close(fig) # Always close the figure to free up memory
    return saved_filename

# %% [markdown]
# ## 5. General Visualization Tasks
# This section focuses on loading, processing, and visualizing radar data, including time-distance plots and a single aggregated Range-Azimuth beamformed image.

# %%
def run_visualization_pipeline(
    base_file: str,
    stabilization_frames: int = 20,
    num_angles: int = 31,
    vis_time_window_frames: int = 40 # Total frames for visualization (e.g., 2 seconds of data)
):
    """
    Orchestrates the visualization pipeline: loads, declutters, beamforms,
    and displays time-distance and range-angle plots for a single radar file.

    Args:
        base_file (str): Path to the '_sr250_rx0.npy' file.
        stabilization_frames (int): Number of initial frames to remove after decluttering.
        num_angles (int): Number of azimuth angles to consider for beamforming.
        averaging_mode (int): 0 for coherent, 1 for incoherent sum, 2 for incoherent mean averaging
                              over the visualization time window.
        vis_time_window_frames (int): Number of time frames to aggregate for the final Range-Azimuth plot.
    """
    print(f"\n--- Running Visualization Pipeline for: {os.path.basename(base_file)} ---")
    
    # Generate beam steering angles for visualization
    beam_steering_angles_vis = np.deg2rad(np.linspace(min_angle_deg, max_angle_deg, num_angles))

    # 1. Load and declutter data for all antennas, and optionally show time-distance plot
    all_complex_data = _get_all_decluttered_complex_data(
        base_file,
        stabilization_frames_to_remove=stabilization_frames,
        display_time_distance_plot=True # Display the time-distance plot for this task
    )

    if not all_complex_data:
        print(f"Error: Not enough complex data")
        return

    antenna1_data = all_complex_data[0] # RX0
    antenna2_data = all_complex_data[1] # RX2

    # 2. Perform azimuth beamforming
    print(f"Performing azimuth beamforming using RX0 and RX2 data...")
    beamformed_3d_data = perform_azimuth_beamforming(
        antenna1_data, antenna2_data, d, k, beam_steering_angles_vis
    )
    
    if beamformed_3d_data is None:
        print("Beamforming failed for visualization pipeline.")
        return

    # 3. Aggregate 3D data for 2D Range-Azimuth visualization
    actual_vis_end_frame = min(vis_time_window_frames, beamformed_3d_data.shape[0])
    
    if actual_vis_end_frame == 0:
        print("Not enough frames for visualization after processing and trimming.")
        return
        
    print(f"Aggregating {actual_vis_end_frame} frames for Range-Azimuth plot using coherent averaging...")
    aggregated_beamformed_data_vis = np.abs(np.sum(beamformed_3d_data[0:actual_vis_end_frame, :, ], axis=0))
    
    # 4. Normalize and display the Range-Azimuth plot
    normalized_beamformed_data_vis = normalize_range_angle_map(aggregated_beamformed_data_vis)
    title = f"Beamforming ({actual_vis_end_frame} time frames) - {os.path.basename(base_file).replace('_sr250_rx0.npy', '')}"
    _plot_range_angle_heatmap(
        normalized_beamformed_data_vis, beam_steering_angles_vis, title, show_plot=True
    )
    print("--- Visualization Pipeline Complete ---")

# %%
# Example 1: Coherent averaging with decluttering_ma (W=20)
print("\n--- Running Example 1: Coherent Averaging with MA Decluttering ---")
base_file_for_vis1 = "/kaggle/input/haeeai-project-uwb/SR250Mate/12_Still position_20250618-112436_sr250_rx0.npy"
run_visualization_pipeline(base_file_for_vis1, stabilization_frames=20, vis_time_window_frames=20)

# Example 2: Coherent averaging with decluttering_ewma (alpha=0.9)
print("\n--- Running Example 2: Coherent Averaging with EWMA Decluttering ---")
base_file_for_vis2 = "/kaggle/input/haeeai-project-uwb/SR250Mate/13-12_Still position_20250618-141554_sr250_rx0.npy"
run_visualization_pipeline(base_file_for_vis2, stabilization_frames=20, vis_time_window_frames=20)

# Example 4: Multiple targets with coherent averaging and EWMA
print("\n--- Running Example 3: Multiple Targets (2-4) with Coherent Averaging and EWMA ---")
base_file_for_vis3 = "/kaggle/input/haeeai-project-uwb/SR250Mate/2-4_Still position_20250618-140706_sr250_rx0.npy"
run_visualization_pipeline(base_file_for_vis3, stabilization_frames=20, vis_time_window_frames=20)

# Example 5: Single target with coherent averaging and MA
print("\n--- Running Example 4: Single Target (2) with Coherent Averaging and MA ---")
base_file_for_vis4 = "/kaggle/input/haeeai-project-uwb/SR250Mate/2_Still position_20250618-110517_sr250_rx0.npy"
run_visualization_pipeline(base_file_for_vis4, stabilization_frames=20, vis_time_window_frames=20)

# Example 6: Multiple targets with coherent averaging and MA
print("\n--- Running Example 5: Multiple Targets (4-3) with Coherent Averaging and MA ---")
base_file_for_vis5 = "/kaggle/input/haeeai-project-uwb/SR250Mate/4-3_Still position_20250618-141131_sr250_rx0.npy"
run_visualization_pipeline(base_file_for_vis5, stabilization_frames=20, vis_time_window_frames=20)

# Example 7: Multiple targets (13-8) with coherent averaging and EWMA
print("\n--- Running Example 6: Multiple Targets (13-8) with Coherent Averaging and EWMA ---")
base_file_for_vis6 = "/kaggle/input/haeeai-project-uwb/SR250Mate/13-8_Still position_20250618-142153_sr250_rx0.npy"
run_visualization_pipeline(base_file_for_vis6, stabilization_frames=20, vis_time_window_frames=20)

# Example 7: Multiple targets (13-8) with coherent averaging and EWMA
print("\n--- Running Example 7: Moving targets with Coherent Averaging and MA ---")
base_file_for_vis7 = "/kaggle/input/haeeai-project-uwb/SR250Mate/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004_sr250_rx0.npy"
run_visualization_pipeline(base_file_for_vis7, stabilization_frames=20, vis_time_window_frames=20)
# Out:
# --- Running Example 1: Coherent Averaging with MA Decluttering ---
#
# --- Running Visualization Pipeline for: 12_Still position_20250618-112436_sr250_rx0.npy ---
# Processing antenna files for '12_Still position_20250618-112436_sr250_rx0.npy'...
#   12_Still position_20250618-112436_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   12_Still position_20250618-112436_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Performing azimuth beamforming using RX0 and RX2 data...
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Aggregating 20 frames for Range-Azimuth plot using coherent averaging...
# --- Visualization Pipeline Complete ---
#
# --- Running Example 2: Coherent Averaging with EWMA Decluttering ---
#
# --- Running Visualization Pipeline for: 13-12_Still position_20250618-141554_sr250_rx0.npy ---
# Processing antenna files for '13-12_Still position_20250618-141554_sr250_rx0.npy'...
#   13-12_Still position_20250618-141554_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   13-12_Still position_20250618-141554_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Performing azimuth beamforming using RX0 and RX2 data...
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Aggregating 20 frames for Range-Azimuth plot using coherent averaging...
# --- Visualization Pipeline Complete ---
#
# --- Running Example 3: Multiple Targets (2-4) with Coherent Averaging and EWMA ---
#
# --- Running Visualization Pipeline for: 2-4_Still position_20250618-140706_sr250_rx0.npy ---
# Processing antenna files for '2-4_Still position_20250618-140706_sr250_rx0.npy'...
#   2-4_Still position_20250618-140706_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-4_Still position_20250618-140706_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Performing azimuth beamforming using RX0 and RX2 data...
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Aggregating 20 frames for Range-Azimuth plot using coherent averaging...
# --- Visualization Pipeline Complete ---
#
# --- Running Example 4: Single Target (2) with Coherent Averaging and MA ---
#
# --- Running Visualization Pipeline for: 2_Still position_20250618-110517_sr250_rx0.npy ---
# Processing antenna files for '2_Still position_20250618-110517_sr250_rx0.npy'...
#   2_Still position_20250618-110517_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2_Still position_20250618-110517_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Performing azimuth beamforming using RX0 and RX2 data...
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Aggregating 20 frames for Range-Azimuth plot using coherent averaging...
# --- Visualization Pipeline Complete ---
#
# --- Running Example 5: Multiple Targets (4-3) with Coherent Averaging and MA ---
#
# --- Running Visualization Pipeline for: 4-3_Still position_20250618-141131_sr250_rx0.npy ---
# Processing antenna files for '4-3_Still position_20250618-141131_sr250_rx0.npy'...
#   4-3_Still position_20250618-141131_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-3_Still position_20250618-141131_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Performing azimuth beamforming using RX0 and RX2 data...
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Aggregating 20 frames for Range-Azimuth plot using coherent averaging...
# --- Visualization Pipeline Complete ---
#
# --- Running Example 6: Multiple Targets (13-8) with Coherent Averaging and EWMA ---
#
# --- Running Visualization Pipeline for: 13-8_Still position_20250618-142153_sr250_rx0.npy ---
# Processing antenna files for '13-8_Still position_20250618-142153_sr250_rx0.npy'...
#   13-8_Still position_20250618-142153_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   13-8_Still position_20250618-142153_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Performing azimuth beamforming using RX0 and RX2 data...
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Aggregating 20 frames for Range-Azimuth plot using coherent averaging...
# --- Visualization Pipeline Complete ---
#
# --- Running Example 7: Moving targets with Coherent Averaging and MA ---
#
# --- Running Visualization Pipeline for: (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004_sr250_rx0.npy ---
# Processing antenna files for '(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004_sr250_rx0.npy'...
#   (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004_sr250_rx0.npy processed. Shape after decluttering and frame removal: (6000, 120)
#   (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152004_sr250_rx2.npy processed. Shape after decluttering and frame removal: (6000, 120)
# Performing azimuth beamforming using RX0 and RX2 data...
# Shape of the antennas data after cropping: (6000, 45), with dtype complex64
# Starting beamforming over 6000 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Aggregating 20 frames for Range-Azimuth plot using coherent averaging...
# --- Visualization Pipeline Complete ---

# %% [markdown]
# ## 6. Object Detection Dataset Creation Tasks
# This section focuses on generating a dataset for object detection. It processes radar files in sliding time windows, creates range-angle images, and generates corresponding JSON label files with bounding box annotations.

# %%
# Constants for image generation and bounding boxes for the object detection task
# These dimensions are derived from the original notebook's figsize=(3,3) and dpi=100
# after tight cropping, resulting in an effective content area of roughly 310x308 pixels.
# The num_angles = 31 in this context also influences the width.
IMAGE_WIDTH = 155
IMAGE_HEIGHT = 154

BB_SIZE = 30 # Bounding box size (BB_SIZE x BB_SIZE) in pixels

MIN_DISTANCE = 0
MAX_DISTANCE = 4.5 # Max distance in meters for the range axis visualization

high_dist = round(((IMAGE_HEIGHT / MAX_DISTANCE) * 1) - BB_SIZE / 2, 1) # Position 1.5 meter from radar
med_dist = round(((IMAGE_HEIGHT / MAX_DISTANCE) * 2) - BB_SIZE / 2, 1)  # Position 2.5 meters from radar
low_dist = round(((IMAGE_HEIGHT / MAX_DISTANCE) * 3) - BB_SIZE / 2, 1)  # Position 3.5 meters from radar

left_angle = round((IMAGE_WIDTH * 0.25) - BB_SIZE / 2, 1)
med_angle = round((IMAGE_WIDTH * 0.5) - BB_SIZE / 2, 1)
right_angle = round((IMAGE_WIDTH * 0.75) - BB_SIZE / 2, 1)

# Define the map (position_label) -> (x_coord, y_coord) for bounding box top-left corner
# The labels (2-14) correspond to specific ground truth positions.
# Example: "2" is right, low distance.
positions_map = {
    "2": (right_angle, low_dist),
    "3": (med_angle, low_dist),
    "4": (left_angle, low_dist),
    "7": (right_angle, med_dist),
    "8": (med_angle, med_dist),
    "9": (left_angle, med_dist),
    "12": (right_angle, high_dist),
    "13": (med_angle, high_dist),
    "14": (left_angle, high_dist)
}
print(f"Defined the following positions on an image of size ({IMAGE_WIDTH}, {IMAGE_HEIGHT}): \n{positions_map}\n")

# Define the basic structure of a .labels JSON file for object detection.
DEFAULT_LABELS_STRUCTURE = {
    "version": 1,
    "type": "bounding-box-labels",
    "boundingBoxes": {}
}

# Define constants for the sliding window for dataset creation
WINDOW_SIZE_OD = 40 # The size of each time window for beamforming aggregation (40 frames = 2 seconds)
STEP_SIZE_OD = 20   # The step size for sliding the window (non-overlapping windows)
# Out:
# Defined the following positions on an image of size (155, 154):
# {'2': (101.2, 87.7), '3': (62.5, 87.7), '4': (23.8, 87.7), '7': (101.2, 53.4), '8': (62.5, 53.4), '9': (23.8, 53.4), '12': (101.2, 19.2), '13': (62.5, 19.2), '14': (23.8, 19.2)}

# %% [markdown]
# ### 6.1 Extract Scenario Numbers from Filename
# This function extracts numerical labels from the filename, which indicate the ground truth positions of objects.

# %%
def extract_scenario_numbers(filepath: str) -> List[str]:
    """
    Extracts a list of scenario numbers from a SR250 radar file path.
    These numbers are typically hyphen-separated digits found immediately before
    '_Still position_' or '_Moving position_'.

    Args:
        filepath (str): The full path to the SR250 radar data file.

    Returns:
        List[str]: A list of strings, where each string is an extracted number.
                   Returns an empty list if no such pattern is found.
    """
    filename = os.path.basename(filepath)
    # Pattern to capture hyphen-separated digits followed by optional whitespace
    # and then '_Still position_' or '_Moving position_'.
    pattern = r'([0-9-]+)\s*_(?:Still|Moving) position_'

    match = re.search(pattern, filename)

    if match:
        numbers_str = match.group(1)
        # Split by '-' and filter out any empty strings (e.g., from "2--8-14" or "7-8-9-")
        return [num for num in numbers_str.split('-') if num]
    else:
        return []

# %% [markdown]
# ### 6.2 Generate Object Detection Dataset
# This is the main function for creating the object detection dataset. It iterates through all .npy files, applies beamforming over sliding windows, saves the resulting range-angle heatmaps as images, and creates a consolidated JSON file containing bounding box annotations for each image.

# %%
def generate_od_dataset(
    dataset_base_path: str = "/kaggle/input/haeeai-project-uwb/SR250Mate/",
    output_labels_filename: str = "bounding_boxes.labels",
    output_images_dir: str = "/kaggle/working/gen_images",
    declutter_method_od: str = 'ma',
    declutter_param_od: float = 20, # alpha for EWMA
    stabilization_frames_od: int = 20 # Frames to remove for EWMA stabilization
):
    """
    Processes all SR250 radar data files ending with '_sr250_rx0.npy' in the given dataset path,
    generates beamformed images for sliding time windows, and creates a single consolidated
    JSON labels file with bounding box annotations for all generated images.

    Args:
        dataset_base_path (str): The base directory containing the SR250 radar .npy files.
        output_labels_filename (str): The name of the consolidated .labels JSON file to be created.
        output_images_dir (str): Directory where generated range-angle images will be saved.
        declutter_method_od (str): Decluttering method to use ('ma' or 'ewma').
        declutter_param_od (float): Parameter for the decluttering method (W for 'ma', alpha for 'ewma').
        stabilization_frames_od (int): Number of initial frames to remove after decluttering.
    """
    print(f"--- Starting Object Detection Dataset Generation in: {dataset_base_path} ---")

    consolidated_labels_data = DEFAULT_LABELS_STRUCTURE.copy()
    all_bboxes_for_json = {} 
    
    os.makedirs(output_images_dir, exist_ok=True) # Ensure output directory for images exists

    found_files = []
    for root, _, files in os.walk(dataset_base_path):
        for file in files:
            if file.endswith("_sr250_rx0.npy"):  
                full_filepath = os.path.join(root, file)
                found_files.append(full_filepath)
    
    if not found_files:
        print(f"No '_sr250_rx0.npy' files found in {dataset_base_path}. Exiting.")
        return

    print(f"Found {len(found_files)} radar files to process for OD dataset creation.")

    # Define num_angles specific for the object detection dataset
    num_angles_od = 31
    beam_steering_angles_od = np.deg2rad(np.linspace(min_angle_deg, max_angle_deg, num_angles_od))

    for i, base_filename in enumerate(found_files):
        print(f"\n\nProcessing file {i+1}/{len(found_files)} for OD dataset: {os.path.basename(base_filename)}")
        
        # 1. Extract labels from the filename
        labels = extract_scenario_numbers(base_filename)
        if not labels:
            print(f"  No valid labels found in filename '{os.path.basename(base_filename)}'. Skipping this file.")
            continue
        print("  Extracted labels for this file: ", labels)

        # 2. Load the files, declutter (using specified method for OD), and get complex data
        all_complex_data = _get_all_decluttered_complex_data(
            base_filename,
            stabilization_frames_to_remove=stabilization_frames_od,
            display_time_distance_plot=False
        )

        if not all_complex_data:
            print(f"  Skipping processing of {os.path.basename(base_filename)} due to data loading/decluttering failure.")
            continue 
        
        # Select antenna data for beamforming
        antenna1_data = all_complex_data[0]  # RX0
        antenna2_data = all_complex_data[1]  # RX2

        # 3. Apply beamforming once for the entire data
        # bf_data will be (num_total_frames, range_bins, angles)
        beamformed_3d_data = perform_azimuth_beamforming(
            antenna1_data, antenna2_data, d, k, beam_steering_angles_od
        )

        if beamformed_3d_data is None:
            print(f"  Skipping processing of {os.path.basename(base_filename)} due to beamforming failure.")
            continue 
        
        num_total_frames = beamformed_3d_data.shape[0]
        print(f"  Total time frames available for {os.path.basename(base_filename)}: {num_total_frames}")

        # 4. Create the common bounding box list for this original file based on extracted labels
        common_bboxes_for_this_file = []
        for label_str in labels:
            if not label_str:
                continue
            if label_str in positions_map:
                x_coord, y_coord = positions_map[label_str]
                bbox = {
                    "label": label_str,
                    "x": float(x_coord),
                    "y": float(y_coord),
                    "width": float(BB_SIZE),
                    "height": float(BB_SIZE)
                }
                common_bboxes_for_this_file.append(bbox)
            else:
                print(f"  Warning: Label '{label_str}' extracted from '{os.path.basename(base_filename)}' "
                      f"not found in positions_map. Skipping bounding box for it.")

        # 5. Iterate through sliding windows and generate images and JSON entries
        for start_tf in range(0, num_total_frames - WINDOW_SIZE_OD + 1, STEP_SIZE_OD):
            end_tf = start_tf + WINDOW_SIZE_OD
            
            # print(f"  Processing window {start_tf}-{end_tf} for image generation...")

            # Apply coherent averaging over the specified time window
            aggregated_beamformed_data = np.abs(np.sum(beamformed_3d_data[start_tf:end_tf, :, ], axis=0))
            
            # Normalization for visualization
            normalized_beamformed_data = normalize_range_angle_map(aggregated_beamformed_data)
            
            # Construct the title/filename base
            base_file_part = os.path.basename(base_filename).replace('_sr250_rx0.npy', '')
            image_title = f"{base_file_part}__{start_tf}-{end_tf}"
            
            # Call the unified plotting function to save the image
            generated_image_filename = _plot_range_angle_heatmap(
                normalized_beamformed_data,
                beam_steering_angles_od,
                title=image_title,
                output_dir=output_images_dir,
                show_plot=False, # Do not display, just save
                image_width_px=IMAGE_WIDTH,
                image_height_px=IMAGE_HEIGHT
            )
            
            if generated_image_filename:
                # Add the bounding boxes for this specific window's image to the consolidated dictionary.
                all_bboxes_for_json[generated_image_filename] = common_bboxes_for_this_file

        # Free up memory
        del beamformed_3d_data
        gc.collect()

    # 6. Populate the consolidated JSON structure and write it to a single file
    consolidated_labels_data["boundingBoxes"] = all_bboxes_for_json
    
    final_labels_filepath = os.path.join(output_images_dir, output_labels_filename)

    try:
        with open(final_labels_filepath, 'w') as f:
            json.dump(consolidated_labels_data, f, indent=2) 
        print(f"\n--- Successfully wrote all consolidated bounding box labels to: {final_labels_filepath} ---")
    except Exception as e:
        print(f"\n--- [ERROR] Error writing consolidated JSON file {final_labels_filepath}: {e} ---")
    
    print("\n--- Object Detection Dataset Generation Complete ---")

# %% [markdown]
# #### Example of Object Detection Dataset Creation

# %%
# Run the object detection dataset generation pipeline
# Note: This will create a directory '/kaggle/working/generated_od_images'
# and save images and the bounding_boxes.labels file within it.
# The `dataset_base_path` needs to be correctly set to where your SR250Mate data is.
generate_od_dataset(
    dataset_base_path="/kaggle/input/haeeai-project-uwb/SR250Mate/",
    output_labels_filename="bounding_boxes.labels",
    output_images_dir="/kaggle/working/gen-imgs/",
    stabilization_frames_od=20
)
# Out:
# --- Starting Object Detection Dataset Generation in: /kaggle/input/haeeai-project-uwb/SR250Mate/ ---
# Found 90 radar files to process for OD dataset creation.
#
#
# Processing file 1/90 for OD dataset: 13-14_Still position_20250618-141413_sr250_rx0.npy
#   Extracted labels for this file:  ['13', '14']
# Processing antenna files for '13-14_Still position_20250618-141413_sr250_rx0.npy'...
#   13-14_Still position_20250618-141413_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   13-14_Still position_20250618-141413_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#   Total time frames available for 13-14_Still position_20250618-141413_sr250_rx0.npy: 1200
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__0-40.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__20-60.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__40-80.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__60-100.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__80-120.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__100-140.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__120-160.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__140-180.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__160-200.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__180-220.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__200-240.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__220-260.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__240-280.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__260-300.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__280-320.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__300-340.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__320-360.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__340-380.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__360-400.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__380-420.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__400-440.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__420-460.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__440-480.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__460-500.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__480-520.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__500-540.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__520-560.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__540-580.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__560-600.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__580-620.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__600-640.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__620-660.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__640-680.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__660-700.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__680-720.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__700-740.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__720-760.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__740-780.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__760-800.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__780-820.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__800-840.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__820-860.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__840-880.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__860-900.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__880-920.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__900-940.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__920-960.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__940-980.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__960-1000.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__980-1020.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__1000-1040.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__1020-1060.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__1040-1080.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__1060-1100.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__1080-1120.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__1100-1140.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__1120-1160.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__1140-1180.png
# Image saved successfully to: /kaggle/working/gen-imgs/13-14_Still position_20250618-141413__1160-1200.png
#
#
# Processing file 2/90 for OD dataset: 7_Still position_20250618-114258_sr250_rx0.npy
#   Extracted labels for this file:  ['7']
# Processing antenna files for '7_Still position_20250618-114258_sr250_rx0.npy'...
#   7_Still position_20250618-114258_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   7_Still position_20250618-114258_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#   Total time frames available for 7_Still position_20250618-114258_sr250_rx0.npy: 1200
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__0-40.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__20-60.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__40-80.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__60-100.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__80-120.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__100-140.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__120-160.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__140-180.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__160-200.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__180-220.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__200-240.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__220-260.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__240-280.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__260-300.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__280-320.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__300-340.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__320-360.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__340-380.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__360-400.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__380-420.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__400-440.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__420-460.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__440-480.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__460-500.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__480-520.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__500-540.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__520-560.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__540-580.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__560-600.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__580-620.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__600-640.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__620-660.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__640-680.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__660-700.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__680-720.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__700-740.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__720-760.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__740-780.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__760-800.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__780-820.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__800-840.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__820-860.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__840-880.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__860-900.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__880-920.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__900-940.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__920-960.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__940-980.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__960-1000.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__980-1020.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__1000-1040.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__1020-1060.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__1040-1080.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__1060-1100.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__1080-1120.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__1100-1140.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__1120-1160.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__1140-1180.png
# Image saved successfully to: /kaggle/working/gen-imgs/7_Still position_20250618-114258__1160-1200.png
#
#
# Processing file 3/90 for OD dataset: (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540_sr250_rx0.npy
#   Extracted labels for this file:  ['2', '12', '9', '3', '13', '14', '4', '8', '13', '2']
# Processing antenna files for '(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540_sr250_rx0.npy'...
#   (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540_sr250_rx0.npy processed. Shape after decluttering and frame removal: (6000, 120)
#   (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540_sr250_rx2.npy processed. Shape after decluttering and frame removal: (6000, 120)
# Shape of the antennas data after cropping: (6000, 45), with dtype complex64
# Starting beamforming over 6000 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#   Total time frames available for (move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540_sr250_rx0.npy: 6000
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__0-40.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__20-60.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__40-80.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__60-100.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__80-120.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__100-140.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__120-160.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__140-180.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__160-200.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__180-220.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__200-240.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__220-260.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__240-280.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__260-300.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__280-320.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__300-340.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__320-360.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__340-380.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__360-400.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__380-420.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__400-440.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__420-460.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__440-480.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__460-500.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__480-520.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__500-540.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__520-560.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__540-580.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__560-600.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__580-620.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__600-640.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__620-660.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__640-680.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__660-700.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__680-720.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__700-740.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__720-760.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__740-780.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__760-800.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__780-820.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__800-840.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__820-860.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__840-880.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__860-900.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__880-920.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__900-940.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__920-960.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__940-980.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__960-1000.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__980-1020.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1000-1040.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1020-1060.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1040-1080.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1060-1100.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1080-1120.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1100-1140.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1120-1160.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1140-1180.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1160-1200.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1180-1220.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1200-1240.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1220-1260.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1240-1280.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1260-1300.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1280-1320.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1300-1340.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1320-1360.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1340-1380.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1360-1400.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1380-1420.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1400-1440.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1420-1460.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1440-1480.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1460-1500.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1480-1520.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1500-1540.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1520-1560.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1540-1580.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1560-1600.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1580-1620.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1600-1640.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1620-1660.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1640-1680.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1660-1700.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1680-1720.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1700-1740.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1720-1760.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1740-1780.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1760-1800.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1780-1820.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1800-1840.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1820-1860.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1840-1880.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1860-1900.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1880-1920.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1900-1940.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1920-1960.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1940-1980.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1960-2000.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__1980-2020.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2000-2040.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2020-2060.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2040-2080.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2060-2100.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2080-2120.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2100-2140.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2120-2160.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2140-2180.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2160-2200.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2180-2220.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2200-2240.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2220-2260.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2240-2280.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2260-2300.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2280-2320.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2300-2340.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2320-2360.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2340-2380.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2360-2400.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2380-2420.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2400-2440.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2420-2460.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2440-2480.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2460-2500.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2480-2520.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2500-2540.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2520-2560.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2540-2580.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2560-2600.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2580-2620.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2600-2640.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2620-2660.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2640-2680.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2660-2700.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2680-2720.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2700-2740.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2720-2760.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2740-2780.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2760-2800.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2780-2820.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2800-2840.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2820-2860.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2840-2880.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2860-2900.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2880-2920.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2900-2940.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2920-2960.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2940-2980.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2960-3000.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__2980-3020.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3000-3040.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3020-3060.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3040-3080.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3060-3100.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3080-3120.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3100-3140.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3120-3160.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3140-3180.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3160-3200.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3180-3220.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3200-3240.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3220-3260.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3240-3280.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3260-3300.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3280-3320.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3300-3340.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3320-3360.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3340-3380.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3360-3400.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3380-3420.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3400-3440.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3420-3460.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3440-3480.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3460-3500.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3480-3520.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3500-3540.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3520-3560.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3540-3580.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3560-3600.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3580-3620.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3600-3640.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3620-3660.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3640-3680.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3660-3700.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3680-3720.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3700-3740.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3720-3760.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3740-3780.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3760-3800.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3780-3820.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3800-3840.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3820-3860.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3840-3880.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3860-3900.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3880-3920.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3900-3940.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3920-3960.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3940-3980.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3960-4000.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__3980-4020.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4000-4040.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4020-4060.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4040-4080.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4060-4100.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4080-4120.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4100-4140.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4120-4160.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4140-4180.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4160-4200.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4180-4220.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4200-4240.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4220-4260.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4240-4280.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4260-4300.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4280-4320.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4300-4340.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4320-4360.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4340-4380.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4360-4400.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4380-4420.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4400-4440.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4420-4460.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4440-4480.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4460-4500.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4480-4520.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4500-4540.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4520-4560.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4540-4580.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4560-4600.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4580-4620.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4600-4640.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4620-4660.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4640-4680.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4660-4700.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4680-4720.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4700-4740.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4720-4760.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4740-4780.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4760-4800.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4780-4820.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4800-4840.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4820-4860.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4840-4880.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4860-4900.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4880-4920.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4900-4940.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4920-4960.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4940-4980.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4960-5000.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__4980-5020.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__5000-5040.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__5020-5060.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__5040-5080.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__5060-5100.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__5080-5120.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__5100-5140.png
# Image saved successfully to: /kaggle/working/gen-imgs/(move)2-12-9-3-13-14-4-8-13-2_Still position_20250618-152540__5120-5160.png
# ...
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__880-920.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__900-940.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__920-960.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__940-980.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__960-1000.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__980-1020.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__1000-1040.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__1020-1060.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__1040-1080.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__1060-1100.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__1080-1120.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__1100-1140.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__1120-1160.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__1140-1180.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-12-13_Still position_20250618-145024__1160-1200.png
#
#
# Processing file 89/90 for OD dataset: 2-3-7-8_Still position_20250618-150354_sr250_rx0.npy
#   Extracted labels for this file:  ['2', '3', '7', '8']
# Processing antenna files for '2-3-7-8_Still position_20250618-150354_sr250_rx0.npy'...
#   2-3-7-8_Still position_20250618-150354_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-3-7-8_Still position_20250618-150354_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#   Total time frames available for 2-3-7-8_Still position_20250618-150354_sr250_rx0.npy: 1200
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__0-40.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__20-60.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__40-80.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__60-100.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__80-120.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__100-140.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__120-160.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__140-180.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__160-200.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__180-220.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__200-240.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__220-260.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__240-280.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__260-300.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__280-320.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__300-340.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__320-360.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__340-380.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__360-400.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__380-420.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__400-440.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__420-460.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__440-480.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__460-500.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__480-520.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__500-540.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__520-560.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__540-580.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__560-600.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__580-620.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__600-640.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__620-660.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__640-680.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__660-700.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__680-720.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__700-740.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__720-760.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__740-780.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__760-800.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__780-820.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__800-840.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__820-860.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__840-880.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__860-900.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__880-920.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__900-940.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__920-960.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__940-980.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__960-1000.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__980-1020.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__1000-1040.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__1020-1060.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__1040-1080.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__1060-1100.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__1080-1120.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__1100-1140.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__1120-1160.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__1140-1180.png
# Image saved successfully to: /kaggle/working/gen-imgs/2-3-7-8_Still position_20250618-150354__1160-1200.png
#
#
# Processing file 90/90 for OD dataset: 4-9-12-14_Still position_20250618-150045_sr250_rx0.npy
#   Extracted labels for this file:  ['4', '9', '12', '14']
# Processing antenna files for '4-9-12-14_Still position_20250618-150045_sr250_rx0.npy'...
#   4-9-12-14_Still position_20250618-150045_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-9-12-14_Still position_20250618-150045_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#   Total time frames available for 4-9-12-14_Still position_20250618-150045_sr250_rx0.npy: 1200
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__0-40.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__20-60.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__40-80.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__60-100.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__80-120.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__100-140.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__120-160.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__140-180.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__160-200.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__180-220.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__200-240.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__220-260.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__240-280.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__260-300.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__280-320.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__300-340.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__320-360.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__340-380.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__360-400.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__380-420.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__400-440.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__420-460.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__440-480.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__460-500.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__480-520.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__500-540.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__520-560.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__540-580.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__560-600.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__580-620.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__600-640.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__620-660.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__640-680.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__660-700.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__680-720.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__700-740.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__720-760.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__740-780.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__760-800.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__780-820.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__800-840.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__820-860.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__840-880.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__860-900.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__880-920.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__900-940.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__920-960.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__940-980.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__960-1000.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__980-1020.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__1000-1040.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__1020-1060.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__1040-1080.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__1060-1100.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__1080-1120.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__1100-1140.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__1120-1160.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__1140-1180.png
# Image saved successfully to: /kaggle/working/gen-imgs/4-9-12-14_Still position_20250618-150045__1160-1200.png
#
# --- Successfully wrote all consolidated bounding box labels to: /kaggle/working/gen-imgs/bounding_boxes.labels ---
#
# --- Object Detection Dataset Generation Complete ---

# %%
import zipfile
import os
import shutil # Import shutil for deleting directories

def compress_output_files_to_zip(output_dir: str, zip_filename: str, cleanup_after_compression: bool = True):
    """
    Compresses all files and subdirectories within a given output directory
    into a single zip file. Optionally deletes the original files after compression.

    Args:
        output_dir (str): The path to the directory containing the files to be compressed.
        zip_filename (str): The desired name for the output zip file (e.g., 'od_dataset.zip').
        cleanup_after_compression (bool): If True, deletes all files and subdirectories
                                          from `output_dir` after successful compression,
                                          except for the created zip file itself.
    """
    if not os.path.exists(output_dir):
        print(f"Error: Output directory '{output_dir}' not found. No files to compress.")
        return

    zip_filepath = os.path.join('/kaggle/working/', zip_filename)
    original_files_to_delete = [] # List to store paths of files/dirs to delete

    print(f"\n--- Starting compression of files in '{output_dir}' to '{zip_filepath}' ---")

    try:
        with zipfile.ZipFile(zip_filepath, 'w', zipfile.ZIP_DEFLATED) as zipf:
            for root, dirs, files in os.walk(output_dir):
                for file in files:
                    file_path = os.path.join(root, file)
                    # Exclude the zip file itself from being added to the archive
                    if file_path == zip_filepath:
                        continue

                    # Store the file path for potential deletion later
                    original_files_to_delete.append(file_path)

                    arcname = os.path.relpath(file_path, output_dir)
                    zipf.write(file_path, arcname)
                    # print(f"  Added '{arcname}' to zip.") # Uncomment for verbose output
                
                # Store directory paths for potential deletion later
                # We add directories *after* files within them are processed,
                # ensuring we don't try to delete a non-empty directory.
                for d in dirs:
                    dir_path = os.path.join(root, d)
                    original_files_to_delete.append(dir_path)

        print(f"--- Successfully compressed all output files to '{zip_filepath}' ---")
        print(f"You can find the zip file in the 'Output' tab of this Kaggle notebook after it finishes running and is saved.")
        print(f"The file path will be: {zip_filepath}")

        if cleanup_after_compression:
            print(f"\n--- Starting cleanup of original files in '{output_dir}' (excluding the zip file) ---")
            for item_path in original_files_to_delete:
                if os.path.exists(item_path):
                    try:
                        if os.path.isfile(item_path):
                            os.remove(item_path)
                        elif os.path.isdir(item_path):
                            shutil.rmtree(item_path)
                    except Exception as e:
                        print(f"  Error deleting '{item_path}': {e}")
            print("--- Cleanup complete ---")

    except Exception as e:
        print(f"Error during compression: {e}")
        # If compression fails, we generally don't want to clean up,
        # as the original files might be the only copies.


output_directory_for_compression = "/kaggle/working/gen-imgs"
output_zip_file_name = "od_dataset.zip"
compress_output_files_to_zip(output_directory_for_compression, output_zip_file_name, cleanup_after_compression=True)
# Out:
# --- Starting compression of files in '/kaggle/working/gen-imgs' to '/kaggle/working/od_dataset.zip' ---
# --- Successfully compressed all output files to '/kaggle/working/od_dataset.zip' ---
# You can find the zip file in the 'Output' tab of this Kaggle notebook after it finishes running and is saved.
# The file path will be: /kaggle/working/od_dataset.zip
#
# --- Starting cleanup of original files in '/kaggle/working/gen-imgs' (excluding the zip file) ---
# --- Cleanup complete ---

# %% [markdown]
# ## 7. Blob Detection and Analysis Tasks
# This section focuses on detecting _"blobs"_ (high-intensity regions) at predefined ground truth positions within the beamformed data, typically for evaluating detection performance.

# %%
# Define 9 ground truth positions as (range_bin_idx, angle_idx)
# These indices correspond to the (45 range bins, 46 angles) dimensions
# typically used in the search for best blobs notebook.
ground_truth_positions = {
    "2": (15, 35), # Example: range_bin 15, angle_index 35
    "3": (15, 23),
    "4": (15, 12),
    "7": (25, 35),
    "8": (25, 23),
    "9": (25, 12),
    "12": (35, 35),
    "13": (35, 23),
    "14": (35, 12)
}

# Threshold for detection for normalized values (0 to 1)
detection_threshold = 0.5

# Window parameters for time series blob analysis
WINDOW_SIZE_BLOB_ANALYSIS = 40  # Number of time frames in each analysis window (40 frames = 2 seconds)
STEP_SIZE_BLOB_ANALYSIS = 10    # Step size (stride) for sliding the window

# %% [markdown]
# ### 7.1 Analyze Blobs in Time Windows
# This function analyzes beamformed data in sliding time windows, checking for the blobs at specified ground truth positions based on an intensity threshold. It calculates the average value in a 3x3 neighborhood around each GT position.

# %%
def analyze_blobs_in_time_windows(
    beamformed_3d_data: np.ndarray,
    ground_truth_positions: dict,
    detection_threshold: float,
    window_size_frames: int,
    stride_frames: int,
    gt_labels_to_analyze: Optional[List[str]] = None
) -> dict:
    """
    Analyzes beamformed data in sliding time windows to find "blobs" (high-intensity regions)
    at predefined ground truth positions. It processes each window by coherently summing,
    taking the absolute value, and then normalizing before checking against a threshold.
    Instead of comparing a single point, it computes the average value in a 3x3 neighborhood
    around the specific ground truth position.

    Args:
        beamformed_3d_data (np.ndarray): The 3D beamformed data of shape
                                         (time_frames, range_bins, angles).
                                         Expected to contain complex values.
        ground_truth_positions (dict): A dictionary where keys are GT labels (str)
                                       and values are (range_bin_idx, angle_idx) tuples.
        detection_threshold (float): The normalized magnitude threshold for detection (0 to 1).
        window_size_frames (int): The number of time frames in each window.
        stride_frames (int): The step size (stride) for sliding the window.
        gt_labels_to_analyze (Optional[List[str]]): A list of specific ground truth labels
                                                    (e.g., ["2", "4"]) to analyze.
                                                    If None, all positions in `ground_truth_positions`
                                                    will be analyzed.

    Returns:
        dict: A dictionary where keys are ground truth labels (e.g., "2")
              and values are lists of time frames (start_frame_idx) where
              the blob was detected at that position. Only includes labels that were analyzed.
    """
    num_total_frames = beamformed_3d_data.shape[0]

    if gt_labels_to_analyze is None:
        print("No specific ground truth labels provided for analysis. Analyzing all known GT positions.")
        actual_gt_labels = list(ground_truth_positions.keys())
    else:
        actual_gt_labels = [label for label in gt_labels_to_analyze if label in ground_truth_positions]
        if len(actual_gt_labels) != len(gt_labels_to_analyze):
            missing_labels = set(gt_labels_to_analyze) - set(ground_truth_positions.keys())
            print(f"Warning: The following requested GT labels were not found in `ground_truth_positions` and will be skipped: {list(missing_labels)}")

    if not actual_gt_labels:
        print("No valid ground truth labels to analyze. Returning empty detections.")
        return {}

    detected_windows = {gt_label: [] for gt_label in actual_gt_labels}
    
    print(f"\n--- Analyzing blobs in time windows (Window size: {window_size_frames} frames, Stride: {stride_frames} frames) ---")
    print(f"Total time frames available for analysis: {num_total_frames}")
    print(f"Detection threshold for normalized value: {detection_threshold}")
    print(f"Analyzing only the following GT positions: {actual_gt_labels}")

    for start_frame in range(0, num_total_frames - window_size_frames + 1, stride_frames):
        end_frame = start_frame + window_size_frames
        
        current_window_complex_data = beamformed_3d_data[start_frame:end_frame, :, :]

        # Coherent summation and absolute magnitude
        aggregated_data_2d = np.abs(np.sum(current_window_complex_data, axis=0))

        # Normalize the 2D aggregated data
        normalized_data_2d = normalize_range_angle_map(aggregated_data_2d)

        for gt_label in actual_gt_labels:
            r_idx, a_idx = ground_truth_positions[gt_label]
            
            # Ensure the GT position itself is within bounds
            if not (0 <= r_idx < normalized_data_2d.shape[0] and 0 <= a_idx < normalized_data_2d.shape[1]):
                # print(f"Warning: GT position '{gt_label}' ({r_idx}, {a_idx}) is out of bounds for matrix shape {normalized_data_2d.shape}. Skipping.")
                continue

            # Define 3x3 neighborhood bounds, handling edges
            r_start = max(0, r_idx - 1)
            r_end = min(normalized_data_2d.shape[0] - 1, r_idx + 1)
            a_start = max(0, a_idx - 1)
            a_end = min(normalized_data_2d.shape[1] - 1, a_idx + 1)

            neighborhood_data = normalized_data_2d[r_start:r_end+1, a_start:a_end+1]
            average_value_in_neighborhood = np.mean(neighborhood_data)

            if average_value_in_neighborhood >= detection_threshold:
                detected_windows[gt_label].append(start_frame)

    print("\n--- Blob analysis complete ---")
    for gt_label, frames in detected_windows.items():
        if frames:
            print(f"  '{gt_label}' detected in {len(frames)} windows, starting at frames: {frames[:5]}...") # Show first 5
        else:
            print(f"  '{gt_label}' not detected above threshold in any window.")
            
    return detected_windows

# %% [markdown]
# ### 7.2 Run Blob Detection Pipeline for a Single File
# This function orchestrates the loading, decluttering, beamforming, visualization (with GT highlights), and blob analysis for a single radar file.

# %%
def run_blob_detection_pipeline(
    base_file: str,
    stabilization_frames: int = 20, # W frames removed for MA stabilization
    num_angles: int = 46,
    vis_time_window_frames: int = 40, # Frames for initial visualization
    gt_positions: dict = ground_truth_positions,
    threshold: float = detection_threshold,
    window_size_for_analysis: int = WINDOW_SIZE_BLOB_ANALYSIS,
    stride_for_analysis: int = STEP_SIZE_BLOB_ANALYSIS
) -> Optional[dict]:
    """
    Orchestrates the blob detection pipeline for a single file:
    loads, declutters, beamforms, shows Range-Azimuth plot with GT,
    and performs blob analysis over sliding windows.

    Args:
        base_file (str): Path to the '_sr250_rx0.npy' file.
        stabilization_frames (int): Number of initial frames to remove after decluttering.
        num_angles (int): Number of azimuth angles for beamforming.
        averaging_mode (int): Averaging mode for the initial Range-Azimuth visualization (0: Coherent, 1: Incoherent, 2: Incoherent Mean).
        vis_time_window_frames (int): Number of time frames to aggregate for the initial Range-Azimuth plot.
        gt_positions (dict): Dictionary of ground truth positions.
        threshold (float): Detection threshold for blob analysis.
        window_size_for_analysis (int): Window size for blob analysis.
        stride_for_analysis (int): Stride for blob analysis.

    Returns:
        Optional[dict]: Dictionary of detected blobs (GT label -> list of start frames) or None if processing fails.
    """
    print(f"\n--- Running Blob Detection Pipeline for: {os.path.basename(base_file)} ---")
    
    # Generate beam steering angles for blob analysis
    beam_steering_angles_blob = np.deg2rad(np.linspace(min_angle_deg, max_angle_deg, num_angles))

    # 1. Extract labels from the filename (to highlight and analyze)
    gt_labels_for_this_file = extract_scenario_numbers(base_file)
    print("  Extracted labels for this file: ", gt_labels_for_this_file)

    # Convert GT labels to plot coordinates for highlighting
    gt_coords_for_plot_list = []
    if gt_labels_for_this_file:
        for label in gt_labels_for_this_file:
            if label in gt_positions:
                gt_coords_for_plot_list.append(gt_positions[label])
            else:
                print(f"  Warning: Requested GT label '{label}' not found in ground_truth_positions for plotting.")

    # 2. Load and declutter data
    all_complex_data = _get_all_decluttered_complex_data(
        base_file,
        stabilization_frames_to_remove=stabilization_frames,
        display_time_distance_plot=False
    )

    if not all_complex_data:
        print(f"Error: Not enough complex data.")
        return None

    antenna1_data = all_complex_data[0]  # RX0
    antenna2_data = all_complex_data[1]  # RX2

    # 3. Perform azimuth beamforming
    print(f"Performing azimuth beamforming using RX0 and RX2 data...")
    beamformed_3d_data = perform_azimuth_beamforming(
        antenna1_data, antenna2_data, d, k, beam_steering_angles_blob
    )
    
    if beamformed_3d_data is None:
        print("Beamforming failed for blob detection pipeline.")
        return None

    # 4. Aggregate data for initial Range-Azimuth visualization
    actual_vis_end_frame = min(vis_time_window_frames, beamformed_3d_data.shape[0])
    
    if actual_vis_end_frame == 0:
        print("Not enough frames for visualization after processing and trimming.")
        return None

    print(f"Aggregating {actual_vis_end_frame} frames for initial Range-Azimuth plot...")
    aggregated_beamformed_data_vis = np.abs(np.sum(beamformed_3d_data[0:actual_vis_end_frame, :, ], axis=0))
    
    normalized_beamformed_data_vis = normalize_range_angle_map(aggregated_beamformed_data_vis)
    title = f"Beamforming ({actual_vis_end_frame} frames) with GTs - {os.path.basename(base_file).replace('_sr250_rx0.npy', '')}"
    
    _plot_range_angle_heatmap(
        normalized_beamformed_data_vis,
        beam_steering_angles_blob,
        title,
        show_plot=True,
        gt_highlight_coords_list=gt_coords_for_plot_list
    )
    
    # 5. Perform blob analysis over sliding windows
    detected_blobs = analyze_blobs_in_time_windows(
        beamformed_3d_data,
        gt_positions,
        threshold,
        window_size_for_analysis,
        stride_for_analysis,
        gt_labels_to_analyze=gt_labels_for_this_file
    )
    
    print("\n--- Blob Detection Pipeline Complete ---")
    return detected_blobs

# %% [markdown]
# #### Example of Blob Detection for a Single File

# %%
# Example of blob detection for a specific file
print("\n--- Running Single File Blob Detection Example ---")
base_file_path_blob_example = "/kaggle/input/haeeai-project-uwb/SR250Mate/12-14_Still position_20250618-140951_sr250_rx0.npy"
detected_blobs_single_file = run_blob_detection_pipeline(
    base_file_path_blob_example,
    stabilization_frames=20
)
# Out:
# --- Running Single File Blob Detection Example ---
#
# --- Running Blob Detection Pipeline for: 12-14_Still position_20250618-140951_sr250_rx0.npy ---
#   Extracted labels for this file:  ['12', '14']
# Processing antenna files for '12-14_Still position_20250618-140951_sr250_rx0.npy'...
#   12-14_Still position_20250618-140951_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   12-14_Still position_20250618-140951_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Performing azimuth beamforming using RX0 and RX2 data...
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
# Aggregating 40 frames for initial Range-Azimuth plot...
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['12', '14']
#
# --- Blob analysis complete ---
#   '12' detected in 5 windows, starting at frames: [30, 420, 450, 460, 510]...
#   '14' detected in 1 windows, starting at frames: [1140]...
#
# --- Blob Detection Pipeline Complete ---

# %% [markdown]
# ### 7.3 Aggregate Blob Detections Across All Files
# This function processes all eligible radar files in the dataset, runs the blob detection pipeline, and aggregates the detection counts into a 2D matrix (Ground Truth Label vs. Time Frame Index). This allows for a holistic view of detection performance across the entire dataset.

# %%
def aggregate_blob_detections_across_all_files(
    dataset_base_path: str = "/kaggle/input/haeeai-project-uwb/SR250Mate/",
    max_frame_index_for_plot: int = 1200,
    stabilization_frames_agg: int = 20,
    num_angles_agg: int = 31, # For blob analysis (31 angles from -45 to 45 deg)
    detection_threshold_agg: float = detection_threshold,
    window_size_agg: int = WINDOW_SIZE_BLOB_ANALYSIS,
    stride_agg: int = STEP_SIZE_BLOB_ANALYSIS
):
    """
    Processes all SR250Mate files to aggregate blob detection counts across all time frames
    and ground truth positions, then visualizes the results as a heatmap.

    Args:
        dataset_base_path (str): The base directory containing the SR250 radar .npy files.
        max_frame_index_for_plot (int): The maximum frame index to include on the X-axis of the aggregated plot.
        declutter_method_agg (str): Decluttering method to use.
        declutter_param_agg (float): Parameter for the decluttering method.
        stabilization_frames_agg (int): Number of initial frames to remove after decluttering.
        num_angles_agg (int): Number of azimuth angles for beamforming during aggregation.
        detection_threshold_agg (float): Detection threshold for blob analysis during aggregation.
        window_size_agg (int): Window size for blob analysis during aggregation.
        stride_agg (int): Stride for blob analysis during aggregation.
    """
    print("\n--- Starting Aggregated Blob Detection Across All Files ---")

    # Define the nine ground truth labels in a fixed order for the Y-axis
    gt_labels_ordered = ["2", "3", "4", "7", "8", "9", "12", "13", "14"]
    num_gt_labels = len(gt_labels_ordered)

    num_frames_xaxis = max_frame_index_for_plot + 1 # Because it includes 0

    # Initialize the aggregation matrix with zeros
    blob_detection_counts = np.zeros(
        (num_gt_labels, num_frames_xaxis), dtype=int
    )

    # Create a mapping from GT label to its corresponding row index for easy access
    gt_label_to_row_idx = {label: i for i, label in enumerate(gt_labels_ordered)}

    total_num_files_processed = 0
    
    # Generate beam steering angles for aggregation task
    beam_steering_angles_agg = np.deg2rad(np.linspace(min_angle_deg, max_angle_deg, num_angles_agg))

    for dirname, _, filenames in os.walk(dataset_base_path):
        for filename in filenames:
            # We only process 'rx0.npy' files, and skip "(move)" files as in original notebook
            if filename.endswith("_sr250_rx0.npy") and not filename.startswith("(move)"):
                full_path_filename = os.path.join(dirname, filename)
                print(f"\nProcessing file for aggregation: {full_path_filename}")
                
                # 1. Extract labels (GTs for this specific file)
                current_file_gt_labels = extract_scenario_numbers(full_path_filename)
                if not current_file_gt_labels:
                    print(f"  No valid GT labels found for '{os.path.basename(full_path_filename)}'. Skipping.")
                    continue

                # 2. Load and declutter data
                all_complex_data = _get_all_decluttered_complex_data(
                    full_path_filename,
                    stabilization_frames_to_remove=stabilization_frames_agg,
                    display_time_distance_plot=False
                )

                if not all_complex_data:
                    print(f"  Skipping processing of {os.path.basename(full_path_filename)} due to data loading/decluttering failure.")
                    continue 

                antenna1_data = all_complex_data[0]  # RX0
                antenna2_data = all_complex_data[1]  # RX2

                # 3. Perform azimuth beamforming
                beamformed_3d_data = perform_azimuth_beamforming(
                    antenna1_data, antenna2_data, d, k, beam_steering_angles_agg
                )

                if beamformed_3d_data is None:
                    print(f"  Skipping processing of {os.path.basename(full_path_filename)} due to beamforming failure.")
                    continue 
                
                # 4. Perform blob analysis
                current_file_detections = analyze_blobs_in_time_windows(
                    beamformed_3d_data,
                    ground_truth_positions,
                    detection_threshold_agg,
                    window_size_agg,
                    stride_agg,
                    gt_labels_to_analyze=current_file_gt_labels
                )

                # Free up memory
                del beamformed_3d_data
                gc.collect()

                if current_file_detections:
                    total_num_files_processed += 1
                    # 5. Aggregate detections into the matrix
                    for gt_label, detected_frames_list in current_file_detections.items():
                        if gt_label in gt_label_to_row_idx and detected_frames_list:
                            row_idx = gt_label_to_row_idx[gt_label]
                            for frame_idx in detected_frames_list:
                                # Only increment if the frame_idx is within our desired X-axis range
                                if 0 <= frame_idx <= max_frame_index_for_plot:
                                    blob_detection_counts[row_idx, frame_idx] += 1
                                else:
                                    print(f"  Warning: Detected frame {frame_idx} for GT '{gt_label}' is out of the [0, {max_frame_index_for_plot}] range. Skipping count for this frame.")
                else:
                    print(f"  No blob detections returned for {os.path.basename(full_path_filename)}, or analysis failed.")

    print(f"\n--- Finished processing {total_num_files_processed} eligible files for aggregation. ---")
    print(f"Aggregation matrix shape: {blob_detection_counts.shape}")

    # --- Visualization of the aggregated 2D matrix ---
    print("\nGenerating aggregated blob detection heatmap...")

    plt.figure(figsize=(15, 8))
    im = plt.imshow(
        blob_detection_counts,
        aspect='auto',
        origin='lower',  # Keep origin lower so frame 0 is at the bottom of the y-axis
        cmap='viridis',   # Or 'hot', 'magma', 'Greys', etc.
        interpolation='nearest'
    )

    plt.title('Aggregated Blob Detections Across All Files')
    plt.xlabel('Time Frame Index (start of window)')
    plt.ylabel('Ground Truth Position Label')
    plt.colorbar(im, label='Number of Detections')

    # Set X-axis ticks to show meaningful intervals (e.g., every 100 frames)
    x_ticks_interval = 100
    plt.xticks(np.arange(0, num_frames_xaxis, x_ticks_interval))

    # Set Y-axis ticks to show the GT labels
    plt.yticks(np.arange(num_gt_labels), gt_labels_ordered)

    plt.tight_layout()
    plt.show()
    plt.close() # Close the figure to free memory
    print("\n--- Aggregated Blob Detection Complete ---")

# %% [markdown]
# #### Run Aggregated Blob Detection

# %%
# Run the aggregated blob detection pipeline across the entire dataset
aggregate_blob_detections_across_all_files(
    dataset_base_path="/kaggle/input/haeeai-project-uwb/SR250Mate/",
    max_frame_index_for_plot=1200, # Max X-axis frame index for the plot
    stabilization_frames_agg=20
)
# Out:
# --- Starting Aggregated Blob Detection Across All Files ---
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/13-14_Still position_20250618-141413_sr250_rx0.npy
# Processing antenna files for '13-14_Still position_20250618-141413_sr250_rx0.npy'...
#   13-14_Still position_20250618-141413_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   13-14_Still position_20250618-141413_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['13', '14']
#
# --- Blob analysis complete ---
#   '13' detected in 2 windows, starting at frames: [640, 1030]...
#   '14' detected in 1 windows, starting at frames: [1030]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/7_Still position_20250618-114258_sr250_rx0.npy
# Processing antenna files for '7_Still position_20250618-114258_sr250_rx0.npy'...
#   7_Still position_20250618-114258_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   7_Still position_20250618-114258_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['7']
#
# --- Blob analysis complete ---
#   '7' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3-13_Still position_20250618-142324_sr250_rx0.npy
# Processing antenna files for '3-13_Still position_20250618-142324_sr250_rx0.npy'...
#   3-13_Still position_20250618-142324_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3-13_Still position_20250618-142324_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3', '13']
#
# --- Blob analysis complete ---
#   '3' detected in 106 windows, starting at frames: [10, 30, 40, 60, 70]...
#   '13' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-7-9-14_Still position_20250618-145452_sr250_rx0.npy
# Processing antenna files for '2-7-9-14_Still position_20250618-145452_sr250_rx0.npy'...
#   2-7-9-14_Still position_20250618-145452_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-7-9-14_Still position_20250618-145452_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '7', '9', '14']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '7' not detected above threshold in any window.
#   '9' detected in 2 windows, starting at frames: [250, 290]...
#   '14' detected in 1 windows, starting at frames: [930]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-4-9-14_Still position_20250618-145914_sr250_rx0.npy
# Processing antenna files for '2-4-9-14_Still position_20250618-145914_sr250_rx0.npy'...
#   2-4-9-14_Still position_20250618-145914_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-4-9-14_Still position_20250618-145914_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '4', '9', '14']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '4' detected in 113 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '9' not detected above threshold in any window.
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/12_Still position_20250618-112436_sr250_rx0.npy
# Processing antenna files for '12_Still position_20250618-112436_sr250_rx0.npy'...
#   12_Still position_20250618-112436_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   12_Still position_20250618-112436_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['12']
#
# --- Blob analysis complete ---
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2_Still position_20250618-114923_sr250_rx0.npy
# Processing antenna files for '2_Still position_20250618-114923_sr250_rx0.npy'...
#   2_Still position_20250618-114923_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2_Still position_20250618-114923_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/8-12_Still position_20250618-150939_sr250_rx0.npy
# Processing antenna files for '8-12_Still position_20250618-150939_sr250_rx0.npy'...
#   8-12_Still position_20250618-150939_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   8-12_Still position_20250618-150939_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['8', '12']
#
# --- Blob analysis complete ---
#   '8' detected in 64 windows, starting at frames: [0, 20, 30, 40, 50]...
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/7-12_Still position_20250618-142914_sr250_rx0.npy
# Processing antenna files for '7-12_Still position_20250618-142914_sr250_rx0.npy'...
#   7-12_Still position_20250618-142914_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   7-12_Still position_20250618-142914_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['7', '12']
#
# --- Blob analysis complete ---
#   '7' not detected above threshold in any window.
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-4-12-14_Still position_20250618-144012_sr250_rx0.npy
# Processing antenna files for '2-4-12-14_Still position_20250618-144012_sr250_rx0.npy'...
#   2-4-12-14_Still position_20250618-144012_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-4-12-14_Still position_20250618-144012_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '4', '12', '14']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '4' detected in 113 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '12' not detected above threshold in any window.
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-9-14_Still position_20250618-135759_sr250_rx0.npy
# Processing antenna files for '4-9-14_Still position_20250618-135759_sr250_rx0.npy'...
#   4-9-14_Still position_20250618-135759_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-9-14_Still position_20250618-135759_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '9', '14']
#
# --- Blob analysis complete ---
#   '4' detected in 115 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '9' not detected above threshold in any window.
#   '14' detected in 1 windows, starting at frames: [770]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3-12-14_Still position_20250618-120129_sr250_rx0.npy
# Processing antenna files for '3-12-14_Still position_20250618-120129_sr250_rx0.npy'...
#   3-12-14_Still position_20250618-120129_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3-12-14_Still position_20250618-120129_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3', '12', '14']
#
# --- Blob analysis complete ---
#   '3' detected in 78 windows, starting at frames: [10, 20, 30, 40, 70]...
#   '12' not detected above threshold in any window.
#   '14' detected in 1 windows, starting at frames: [140]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/8_Still position_20250618-110927_sr250_rx0.npy
# Processing antenna files for '8_Still position_20250618-110927_sr250_rx0.npy'...
#   8_Still position_20250618-110927_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   8_Still position_20250618-110927_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['8']
#
# --- Blob analysis complete ---
#   '8' detected in 53 windows, starting at frames: [50, 100, 110, 130, 140]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/7_Still position_(250,45)_20250618-105902_sr250_rx0.npy
# Processing antenna files for '7_Still position_(250,45)_20250618-105902_sr250_rx0.npy'...
#   7_Still position_(250,45)_20250618-105902_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   7_Still position_(250,45)_20250618-105902_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['7']
#
# --- Blob analysis complete ---
#   '7' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/7-8_Still position_20250618-141728_sr250_rx0.npy
# Processing antenna files for '7-8_Still position_20250618-141728_sr250_rx0.npy'...
#   7-8_Still position_20250618-141728_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   7-8_Still position_20250618-141728_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['7', '8']
#
# --- Blob analysis complete ---
#   '7' not detected above threshold in any window.
#   '8' detected in 49 windows, starting at frames: [10, 20, 30, 50, 60]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/8-14_Still position_20250618-151230_sr250_rx0.npy
# Processing antenna files for '8-14_Still position_20250618-151230_sr250_rx0.npy'...
#   8-14_Still position_20250618-151230_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   8-14_Still position_20250618-151230_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['8', '14']
#
# --- Blob analysis complete ---
#   '8' detected in 31 windows, starting at frames: [20, 40, 50, 80, 110]...
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/7_Still position_20250618-112028_sr250_rx0.npy
# Processing antenna files for '7_Still position_20250618-112028_sr250_rx0.npy'...
#   7_Still position_20250618-112028_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   7_Still position_20250618-112028_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['7']
#
# --- Blob analysis complete ---
#   '7' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3-9-7-13_Still position_20250618-144439_sr250_rx0.npy
# Processing antenna files for '3-9-7-13_Still position_20250618-144439_sr250_rx0.npy'...
#   3-9-7-13_Still position_20250618-144439_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3-9-7-13_Still position_20250618-144439_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3', '9', '7', '13']
#
# --- Blob analysis complete ---
#   '3' detected in 100 windows, starting at frames: [0, 10, 20, 30, 50]...
#   '9' detected in 13 windows, starting at frames: [10, 70, 80, 130, 140]...
#   '7' not detected above threshold in any window.
#   '13' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3-8-12_Still position_20250618-135138_sr250_rx0.npy
# Processing antenna files for '3-8-12_Still position_20250618-135138_sr250_rx0.npy'...
#   3-8-12_Still position_20250618-135138_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3-8-12_Still position_20250618-135138_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3', '8', '12']
#
# --- Blob analysis complete ---
#   '3' detected in 97 windows, starting at frames: [0, 10, 20, 30, 50]...
#   '8' not detected above threshold in any window.
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-9-12_Still position_20250618-120530_sr250_rx0.npy
# Processing antenna files for '4-9-12_Still position_20250618-120530_sr250_rx0.npy'...
#   4-9-12_Still position_20250618-120530_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-9-12_Still position_20250618-120530_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '9', '12']
#
# --- Blob analysis complete ---
#   '4' detected in 112 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '9' not detected above threshold in any window.
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/7-9-13_Still position_20250618-115741_sr250_rx0.npy
# Processing antenna files for '7-9-13_Still position_20250618-115741_sr250_rx0.npy'...
#   7-9-13_Still position_20250618-115741_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   7-9-13_Still position_20250618-115741_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['7', '9', '13']
#
# --- Blob analysis complete ---
#   '7' not detected above threshold in any window.
#   '9' detected in 49 windows, starting at frames: [40, 50, 60, 70, 80]...
#   '13' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/8_Still position_20250618-112157_sr250_rx0.npy
# Processing antenna files for '8_Still position_20250618-112157_sr250_rx0.npy'...
#   8_Still position_20250618-112157_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   8_Still position_20250618-112157_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['8']
#
# --- Blob analysis complete ---
#   '8' detected in 72 windows, starting at frames: [30, 40, 50, 70, 80]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3-8-14_Still position_20250618-135318_sr250_rx0.npy
# Processing antenna files for '3-8-14_Still position_20250618-135318_sr250_rx0.npy'...
#   3-8-14_Still position_20250618-135318_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3-8-14_Still position_20250618-135318_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3', '8', '14']
#
# --- Blob analysis complete ---
#   '3' detected in 112 windows, starting at frames: [0, 10, 20, 40, 50]...
#   '8' not detected above threshold in any window.
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/7-8-9-_Still position_20250618-140354_sr250_rx0.npy
# Processing antenna files for '7-8-9-_Still position_20250618-140354_sr250_rx0.npy'...
#   7-8-9-_Still position_20250618-140354_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   7-8-9-_Still position_20250618-140354_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['7', '8', '9']
#
# --- Blob analysis complete ---
#   '7' not detected above threshold in any window.
#   '8' detected in 51 windows, starting at frames: [0, 10, 20, 40, 50]...
#   '9' detected in 58 windows, starting at frames: [0, 10, 20, 40, 50]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-4-7-12_Still position_20250618-145748_sr250_rx0.npy
# Processing antenna files for '2-4-7-12_Still position_20250618-145748_sr250_rx0.npy'...
#   2-4-7-12_Still position_20250618-145748_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-4-7-12_Still position_20250618-145748_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '4', '7', '12']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '4' detected in 108 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '7' not detected above threshold in any window.
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-3_Still position_20250618-141851_sr250_rx0.npy
# Processing antenna files for '2-3_Still position_20250618-141851_sr250_rx0.npy'...
#   2-3_Still position_20250618-141851_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-3_Still position_20250618-141851_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '3']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '3' detected in 67 windows, starting at frames: [0, 10, 50, 60, 80]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3_Still position_20250618-111255_sr250_rx0.npy
# Processing antenna files for '3_Still position_20250618-111255_sr250_rx0.npy'...
#   3_Still position_20250618-111255_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3_Still position_20250618-111255_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3']
#
# --- Blob analysis complete ---
#   '3' detected in 108 windows, starting at frames: [0, 10, 20, 30, 40]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3-8-13_Still position_20250618-135924_sr250_rx0.npy
# Processing antenna files for '3-8-13_Still position_20250618-135924_sr250_rx0.npy'...
#   3-8-13_Still position_20250618-135924_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3-8-13_Still position_20250618-135924_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3', '8', '13']
#
# --- Blob analysis complete ---
#   '3' detected in 96 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '8' not detected above threshold in any window.
#   '13' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/12-14_Still position_20250618-140951_sr250_rx0.npy
# Processing antenna files for '12-14_Still position_20250618-140951_sr250_rx0.npy'...
#   12-14_Still position_20250618-140951_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   12-14_Still position_20250618-140951_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['12', '14']
#
# --- Blob analysis complete ---
#   '12' not detected above threshold in any window.
#   '14' detected in 3 windows, starting at frames: [30, 200, 1140]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3-4-12-13_Still position_20250618-144608_sr250_rx0.npy
# Processing antenna files for '3-4-12-13_Still position_20250618-144608_sr250_rx0.npy'...
#   3-4-12-13_Still position_20250618-144608_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3-4-12-13_Still position_20250618-144608_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3', '4', '12', '13']
#
# --- Blob analysis complete ---
#   '3' detected in 108 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '4' detected in 114 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '12' not detected above threshold in any window.
#   '13' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/9_Still position_20250618-114541_sr250_rx0.npy
# Processing antenna files for '9_Still position_20250618-114541_sr250_rx0.npy'...
#   9_Still position_20250618-114541_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   9_Still position_20250618-114541_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['9']
#
# --- Blob analysis complete ---
#   '9' detected in 54 windows, starting at frames: [0, 10, 30, 70, 90]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-2-14 _Still position_20250618-115434_sr250_rx0.npy
# Processing antenna files for '4-2-14 _Still position_20250618-115434_sr250_rx0.npy'...
#   4-2-14 _Still position_20250618-115434_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-2-14 _Still position_20250618-115434_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '2', '14']
#
# --- Blob analysis complete ---
#   '4' detected in 108 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '2' not detected above threshold in any window.
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-7-9-12_Still position_20250618-145620_sr250_rx0.npy
# Processing antenna files for '4-7-9-12_Still position_20250618-145620_sr250_rx0.npy'...
#   4-7-9-12_Still position_20250618-145620_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-7-9-12_Still position_20250618-145620_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '7', '9', '12']
#
# --- Blob analysis complete ---
#   '4' detected in 94 windows, starting at frames: [0, 10, 20, 30, 60]...
#   '7' not detected above threshold in any window.
#   '9' detected in 14 windows, starting at frames: [180, 350, 360, 400, 460]...
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/8-9_Still position_20250618-141253_sr250_rx0.npy
# Processing antenna files for '8-9_Still position_20250618-141253_sr250_rx0.npy'...
#   8-9_Still position_20250618-141253_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   8-9_Still position_20250618-141253_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['8', '9']
#
# --- Blob analysis complete ---
#   '8' detected in 50 windows, starting at frames: [20, 60, 70, 80, 100]...
#   '9' detected in 52 windows, starting at frames: [30, 70, 80, 140, 170]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/12-13-14_Still position_20250618-140232_sr250_rx0.npy
# Processing antenna files for '12-13-14_Still position_20250618-140232_sr250_rx0.npy'...
#   12-13-14_Still position_20250618-140232_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   12-13-14_Still position_20250618-140232_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['12', '13', '14']
#
# --- Blob analysis complete ---
#   '12' not detected above threshold in any window.
#   '13' detected in 2 windows, starting at frames: [800, 930]...
#   '14' detected in 3 windows, starting at frames: [380, 830, 930]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-9_Still position_20250618-143050_sr250_rx0.npy
# Processing antenna files for '4-9_Still position_20250618-143050_sr250_rx0.npy'...
#   4-9_Still position_20250618-143050_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-9_Still position_20250618-143050_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '9']
#
# --- Blob analysis complete ---
#   '4' detected in 110 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '9' detected in 1 windows, starting at frames: [610]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2--8-14_Still position_20250618-135452_sr250_rx0.npy
# Processing antenna files for '2--8-14_Still position_20250618-135452_sr250_rx0.npy'...
#   2--8-14_Still position_20250618-135452_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2--8-14_Still position_20250618-135452_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '8', '14']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '8' detected in 17 windows, starting at frames: [0, 90, 100, 110, 120]...
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/12_Still position_20250618-114145_sr250_rx0.npy
# Processing antenna files for '12_Still position_20250618-114145_sr250_rx0.npy'...
#   12_Still position_20250618-114145_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   12_Still position_20250618-114145_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['12']
#
# --- Blob analysis complete ---
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4_Still position_20250618-114655_sr250_rx0.npy
# Processing antenna files for '4_Still position_20250618-114655_sr250_rx0.npy'...
#   4_Still position_20250618-114655_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4_Still position_20250618-114655_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4']
#
# --- Blob analysis complete ---
#   '4' detected in 96 windows, starting at frames: [0, 10, 20, 30, 60]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/14_Still position_20250618-112731_sr250_rx0.npy
# Processing antenna files for '14_Still position_20250618-112731_sr250_rx0.npy'...
#   14_Still position_20250618-112731_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   14_Still position_20250618-112731_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['14']
#
# --- Blob analysis complete ---
#   '14' detected in 2 windows, starting at frames: [230, 370]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-12-14 _Still position_20250618-115119_sr250_rx0.npy
# Processing antenna files for '2-12-14 _Still position_20250618-115119_sr250_rx0.npy'...
#   2-12-14 _Still position_20250618-115119_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-12-14 _Still position_20250618-115119_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '12', '14']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '12' not detected above threshold in any window.
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3-4-13-14_Still position_20250618-144858_sr250_rx0.npy
# Processing antenna files for '3-4-13-14_Still position_20250618-144858_sr250_rx0.npy'...
#   3-4-13-14_Still position_20250618-144858_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3-4-13-14_Still position_20250618-144858_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3', '4', '13', '14']
#
# --- Blob analysis complete ---
#   '3' detected in 110 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '4' detected in 111 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '13' detected in 1 windows, starting at frames: [190]...
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/13_Still position_20250618-114029_sr250_rx0.npy
# Processing antenna files for '13_Still position_20250618-114029_sr250_rx0.npy'...
#   13_Still position_20250618-114029_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   13_Still position_20250618-114029_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['13']
#
# --- Blob analysis complete ---
#   '13' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/14-2_Still position_20250618-151512_sr250_rx0.npy
# Processing antenna files for '14-2_Still position_20250618-151512_sr250_rx0.npy'...
#   14-2_Still position_20250618-151512_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   14-2_Still position_20250618-151512_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['14', '2']
#
# --- Blob analysis complete ---
#   '14' not detected above threshold in any window.
#   '2' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-8_Still position_20250618-151109_sr250_rx0.npy
# Processing antenna files for '2-8_Still position_20250618-151109_sr250_rx0.npy'...
#   2-8_Still position_20250618-151109_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-8_Still position_20250618-151109_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '8']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '8' detected in 4 windows, starting at frames: [500, 550, 580, 590]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-8_Still position_20250618-143357_sr250_rx0.npy
# Processing antenna files for '4-8_Still position_20250618-143357_sr250_rx0.npy'...
#   4-8_Still position_20250618-143357_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-8_Still position_20250618-143357_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# ...
#   4_Still position_20250618-111410_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4_Still position_20250618-111410_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4']
#
# --- Blob analysis complete ---
#   '4' detected in 114 windows, starting at frames: [0, 10, 20, 30, 40]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-12-14 _Still position_20250618-115246_sr250_rx0.npy
# Processing antenna files for '4-12-14 _Still position_20250618-115246_sr250_rx0.npy'...
#   4-12-14 _Still position_20250618-115246_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-12-14 _Still position_20250618-115246_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '12', '14']
#
# --- Blob analysis complete ---
#   '4' detected in 112 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '12' not detected above threshold in any window.
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-3-13-14_Still position_20250618-144727_sr250_rx0.npy
# Processing antenna files for '2-3-13-14_Still position_20250618-144727_sr250_rx0.npy'...
#   2-3-13-14_Still position_20250618-144727_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-3-13-14_Still position_20250618-144727_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '3', '13', '14']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '3' detected in 106 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '13' not detected above threshold in any window.
#   '14' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/14_Still position_20250618-113914_sr250_rx0.npy
# Processing antenna files for '14_Still position_20250618-113914_sr250_rx0.npy'...
#   14_Still position_20250618-113914_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   14_Still position_20250618-113914_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['14']
#
# --- Blob analysis complete ---
#   '14' detected in 1 windows, starting at frames: [440]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-7-12_Still position_20250618-140100_sr250_rx0.npy
# Processing antenna files for '2-7-12_Still position_20250618-140100_sr250_rx0.npy'...
#   2-7-12_Still position_20250618-140100_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-7-12_Still position_20250618-140100_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '7', '12']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '7' not detected above threshold in any window.
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/3-4-8-9_Still position_20250618-150521_sr250_rx0.npy
# Processing antenna files for '3-4-8-9_Still position_20250618-150521_sr250_rx0.npy'...
#   3-4-8-9_Still position_20250618-150521_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   3-4-8-9_Still position_20250618-150521_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['3', '4', '8', '9']
#
# --- Blob analysis complete ---
#   '3' detected in 115 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '4' detected in 116 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '8' not detected above threshold in any window.
#   '9' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/13_Still position_20250618-112555_sr250_rx0.npy
# Processing antenna files for '13_Still position_20250618-112555_sr250_rx0.npy'...
#   13_Still position_20250618-112555_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   13_Still position_20250618-112555_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['13']
#
# --- Blob analysis complete ---
#   '13' detected in 1 windows, starting at frames: [220]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/8_Still position_20250618-114420_sr250_rx0.npy
# Processing antenna files for '8_Still position_20250618-114420_sr250_rx0.npy'...
#   8_Still position_20250618-114420_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   8_Still position_20250618-114420_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['8']
#
# --- Blob analysis complete ---
#   '8' detected in 40 windows, starting at frames: [60, 100, 120, 140, 150]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-3_Still position_20250618-141131_sr250_rx0.npy
# Processing antenna files for '4-3_Still position_20250618-141131_sr250_rx0.npy'...
#   4-3_Still position_20250618-141131_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-3_Still position_20250618-141131_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '3']
#
# --- Blob analysis complete ---
#   '4' detected in 116 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '3' detected in 115 windows, starting at frames: [10, 20, 30, 40, 50]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-8-12_Still position_20250618-135625_sr250_rx0.npy
# Processing antenna files for '4-8-12_Still position_20250618-135625_sr250_rx0.npy'...
#   4-8-12_Still position_20250618-135625_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-8-12_Still position_20250618-135625_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '8', '12']
#
# --- Blob analysis complete ---
#   '4' detected in 106 windows, starting at frames: [0, 10, 40, 50, 60]...
#   '8' detected in 3 windows, starting at frames: [30, 480, 600]...
#   '12' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2_Still position_20250618-110517_sr250_rx0.npy
# Processing antenna files for '2_Still position_20250618-110517_sr250_rx0.npy'...
#   2_Still position_20250618-110517_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2_Still position_20250618-110517_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-14_Still position_20250618-143220_sr250_rx0.npy
# Processing antenna files for '4-14_Still position_20250618-143220_sr250_rx0.npy'...
#   4-14_Still position_20250618-143220_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-14_Still position_20250618-143220_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '14']
#
# --- Blob analysis complete ---
#   '4' detected in 112 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '14' detected in 8 windows, starting at frames: [140, 160, 180, 210, 220]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-3-12-13_Still position_20250618-145024_sr250_rx0.npy
# Processing antenna files for '2-3-12-13_Still position_20250618-145024_sr250_rx0.npy'...
#   2-3-12-13_Still position_20250618-145024_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-3-12-13_Still position_20250618-145024_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '3', '12', '13']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '3' detected in 97 windows, starting at frames: [0, 20, 30, 50, 60]...
#   '12' not detected above threshold in any window.
#   '13' detected in 1 windows, starting at frames: [100]...
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/2-3-7-8_Still position_20250618-150354_sr250_rx0.npy
# Processing antenna files for '2-3-7-8_Still position_20250618-150354_sr250_rx0.npy'...
#   2-3-7-8_Still position_20250618-150354_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   2-3-7-8_Still position_20250618-150354_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['2', '3', '7', '8']
#
# --- Blob analysis complete ---
#   '2' not detected above threshold in any window.
#   '3' detected in 89 windows, starting at frames: [10, 20, 30, 40, 50]...
#   '7' not detected above threshold in any window.
#   '8' not detected above threshold in any window.
#
# Processing file for aggregation: /kaggle/input/haeeai-project-uwb/SR250Mate/4-9-12-14_Still position_20250618-150045_sr250_rx0.npy
# Processing antenna files for '4-9-12-14_Still position_20250618-150045_sr250_rx0.npy'...
#   4-9-12-14_Still position_20250618-150045_sr250_rx0.npy processed. Shape after decluttering and frame removal: (1200, 120)
#   4-9-12-14_Still position_20250618-150045_sr250_rx2.npy processed. Shape after decluttering and frame removal: (1200, 120)
# Shape of the antennas data after cropping: (1200, 45), with dtype complex64
# Starting beamforming over 1200 time frames and 45 range bins...
# Beamforming complete for all frames and range bins.
#
# --- Analyzing blobs in time windows (Window size: 40 frames, Stride: 10 frames) ---
# Total time frames available for analysis: 1200
# Detection threshold for normalized value: 0.5
# Analyzing only the following GT positions: ['4', '9', '12', '14']
#
# --- Blob analysis complete ---
#   '4' detected in 92 windows, starting at frames: [0, 10, 20, 30, 40]...
#   '9' not detected above threshold in any window.
#   '12' not detected above threshold in any window.
#   '14' not detected above threshold in any window.
#
# --- Finished processing 88 eligible files for aggregation. ---
# Aggregation matrix shape: (9, 1201)
#
# Generating aggregated blob detection heatmap...
# --- Aggregated Blob Detection Complete ---
